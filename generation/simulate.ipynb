# %% [markdown]
# # Generation of BoM Data for Supply Chain Simulation

# %%
SAVE_RECORDS=True

# %%
import sys
sys.path.append("..")

# %%
import random
import pandas as pd
import json

# %% [markdown]
# ## Mock Supply Chain

# %%
from core.supply_chain import SupplyChain, LeafNode, CombinerNode, SinkNode

def create_supply_chain():
    supply_chain = SupplyChain()

    # Create leaf nodes with random cost types
    leaf1 = LeafNode(200, "raw_material_1", [(0, 10), (5, 15), (10, 20)], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    leaf2 = LeafNode(250, "raw_material_2", [(0, 15), (5, 20), (10, 25)], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    leaf3 = LeafNode(220, "raw_material_3", [(0, 12), (5, 18), (10, 22)], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(leaf1)
    supply_chain.add_node(leaf2)
    supply_chain.add_node(leaf3)

    # Create intermediate nodes with random cost types
    intermediate_a1 = CombinerNode(300, "intermediate_a1", [0.8, 1.0], [1, 1.2], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    intermediate_a2 = CombinerNode(280, "intermediate_a2", [0.9, 1.1], [1.1, 1.3], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(intermediate_a1)
    supply_chain.add_node(intermediate_a2)

    intermediate_b1 = CombinerNode(300, "intermediate_b1", [0.8, 1.0], [1, 1.2], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    intermediate_b2 = CombinerNode(280, "intermediate_b2", [0.9, 1.1], [1.1, 1.3], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(intermediate_b1)
    supply_chain.add_node(intermediate_b2)

    # Create final combiner node with random cost type
    final_combiner = CombinerNode(350, "final_product", [0.7, 0.8, 0.9], [1, 1.1, 1.2], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(final_combiner)

    # Create sink node with random cost type
    sink = SinkNode(consumption_rate=250, cost_type=random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(sink)

    # Add edges with cost ranges
    supply_chain.add_edge(leaf1, intermediate_a1, 10, 30, 5, 15)
    supply_chain.add_edge(leaf2, intermediate_a1, 15, 35, 8, 20)
    supply_chain.add_edge(leaf2, intermediate_a2, 12, 30, 6, 18)
    supply_chain.add_edge(leaf3, intermediate_a2, 14, 32, 7, 19)
    supply_chain.add_edge(intermediate_a1, intermediate_b1, 20, 40, 10, 25)
    supply_chain.add_edge(intermediate_a2, intermediate_b1, 22, 42, 11, 27)
    supply_chain.add_edge(intermediate_b1, final_combiner, 20, 40, 10, 25)
    supply_chain.add_edge(intermediate_b2, final_combiner, 22, 42, 11, 27)
    supply_chain.add_edge(leaf3, final_combiner, 18, 35, 9, 23)
    supply_chain.add_edge(final_combiner, sink, 25, 50, 13, 30)

    return supply_chain

# %%
# Simulation
time = 0
supply_chain = create_supply_chain()

for _ in range(200):  # Simulate for 200 time steps
    supply_chain.update()
    time += 1

    # Print current state
    print(f"Time: {time}")
    for node in supply_chain.nodes:
        print(f"Node ({node.node_class}): Inventory = {node.inventory}, Last Production = {node.last_production}, Cost Type = {node.cost_type}")
        for edge, target_node in node.outgoing_edges:
            print(f"  Edge to {target_node.node_class}: Quantity = {edge.quantity}, Cost = {edge.current_cost:.2f}")
    print("---")
# Out:
# Time: 1
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 30, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 35, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 30, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 32, Cost = 7.38
#   Edge to final_product: Quantity = 35, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 95, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 137, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 42, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 120, Cost Type = fixed
#   Edge to final_product: Quantity = 40, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 42, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 140, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 50, Cost = 13.00
# Node (sink): Inventory = 0, Last Production = 50, Cost Type = positive_dynamic
# ---
# Time: 2
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 160, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 199, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to final_product: Quantity = 202, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 141, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 257, Cost = 13.00
# Node (sink): Inventory = 7, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 3
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 80, Cost Type = fixed
#   Edge to final_product: Quantity = 300, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 43, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 350, Cost = 13.00
# Node (sink): Inventory = 107, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 4
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 144, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 110, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 350, Cost = 13.00
# Node (sink): Inventory = 207, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 5
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 262, Cost = 13.00
# Node (sink): Inventory = 219, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 6
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 258, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 7
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 275, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 8
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 314, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 9
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 331, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 10
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 370, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 11
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 387, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 12
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 426, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 13
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 443, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 14
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 482, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 15
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 499, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 16
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 538, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 17
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 555, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 18
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 594, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 19
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 611, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 20
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 650, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 21
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 667, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 22
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 706, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 23
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 723, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 24
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 762, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 25
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 779, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 26
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 818, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 27
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 835, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 28
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 874, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 29
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 891, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 30
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 930, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 31
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 947, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 32
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 986, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 33
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 1003, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 34
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 1042, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 35
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 1059, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 36
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 1098, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 37
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 1115, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 38
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
# ...
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 5354, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 189
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 5371, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 190
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 5410, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 191
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 5427, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 192
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 5466, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 193
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 5483, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 194
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 5522, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 195
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 5539, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 196
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 5578, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 197
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 5595, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 198
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 5634, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 199
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 19.66
#   Edge to intermediate_a2: Quantity = 7, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 40, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = fixed
#   Edge to final_product: Quantity = 161, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 267, Cost = 13.00
# Node (sink): Inventory = 5651, Last Production = 250, Cost Type = positive_dynamic
# ---
# Time: 200
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = negative_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 19.62
#   Edge to intermediate_a2: Quantity = 6, Cost = 17.95
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_b1: Quantity = 38, Cost = 17.50
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = fixed
#   Edge to final_product: Quantity = 147, Cost = 17.50
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to sink: Quantity = 289, Cost = 13.00
# Node (sink): Inventory = 5690, Last Production = 250, Cost Type = positive_dynamic
# ---

# %% [markdown]
# ## Recording of the simulation

# %%
def simulate_and_collect_data(supply_chain, n_cycles):
    # Initialize DataFrames
    metadata = []
    node_data = []
    edge_data = []
    
    node_id = 0

    # Create metadata and assign unique IDs
    for node in supply_chain.nodes:
        metadata.append({
            'node_id': str(node_id), 
            'node_class': node.node_class,
            'max_inventory': node.max_inventory,
            'cost_type': node.cost_type
        })
        node.id = node_id  # Assign ID to node object for reference
        node_id += 1

    edge_id = 0
    # Create edge metadata
    for edge in supply_chain.edges:
        source_node = None
        target_node = None
        
        for node in supply_chain.nodes:
            if edge in [e for e, _ in node.outgoing_edges]:
                source_node = node
            if edge in [e for e, _ in node.incoming_edges]:
                target_node = node
            if source_node and target_node:
                break
        
        if not source_node or not target_node:
            print(f"Warning: Edge {edge_id} is not properly connected.")
            print(f"Source node: {source_node.node_class if source_node else 'None'}")
            print(f"Target node: {target_node.node_class if target_node else 'None'}")
            continue
        
        metadata.append({
            'edge_id': str(edge_id),
            'source_node_id': str(source_node.id),
            'target_node_id': str(target_node.id),
            'unit_price': edge.unit_price,
            'min_cost': edge.min_cost,
            'max_cost': edge.max_cost
        })
        edge.id = edge_id  # Assign ID to edge object for reference
        edge_id += 1

    # Simulate for n cycles
    for cycle in range(n_cycles):
        supply_chain.update()

        # Collect node data
        for node in supply_chain.nodes:
            node_data.append({
                'cycle': cycle,
                'node_id': str(node.id),
                'inventory': node.inventory,
                'last_production': node.last_production
            })

        # Collect edge data
        for edge in supply_chain.edges:
            if hasattr(edge, 'id'):  # Only collect data for edges that were properly connected
                edge_data.append({
                    'cycle': cycle,
                    'edge_id': str(edge.id),
                    'quantity': edge.quantity,
                    'current_cost': edge.current_cost
                })

    # Create DataFrames
    metadata_df = pd.DataFrame(metadata)
    node_data_df = pd.DataFrame(node_data)
    edge_data_df = pd.DataFrame(edge_data)

    return metadata_df, node_data_df, edge_data_df

# %%
supply_chain = create_supply_chain()
metadata_df, node_data_df, edge_data_df = simulate_and_collect_data(supply_chain, n_cycles=20)

# %%
metadata_df
# Out:
#    node_id       node_class  max_inventory         cost_type edge_id  \
# 0        0   raw_material_1          200.0  negative_dynamic     NaN
# 1        1   raw_material_2          250.0             fixed     NaN
# 2        2   raw_material_3          220.0             fixed     NaN
# 3        3  intermediate_a1          300.0             fixed     NaN
# 4        4  intermediate_a2          280.0  negative_dynamic     NaN
# 5        5  intermediate_b1          300.0             fixed     NaN
# 6        6  intermediate_b2          280.0  negative_dynamic     NaN
# 7        7    final_product          350.0  positive_dynamic     NaN
# 8        8             sink            inf  positive_dynamic     NaN
# 9      NaN              NaN            NaN               NaN       0
# 10     NaN              NaN            NaN               NaN       1
# 11     NaN              NaN            NaN               NaN       2
# 12     NaN              NaN            NaN               NaN       3
# 13     NaN              NaN            NaN               NaN       4
# 14     NaN              NaN            NaN               NaN       5
# 15     NaN              NaN            NaN               NaN       6
# 16     NaN              NaN            NaN               NaN       7
# 17     NaN              NaN            NaN               NaN       8
# 18     NaN              NaN            NaN               NaN       9
#
#    source_node_id target_node_id  unit_price  min_cost  max_cost
# 0             NaN            NaN         NaN       NaN       NaN
# 1             NaN            NaN         NaN       NaN       NaN
# 2             NaN            NaN         NaN       NaN       NaN
# 3             NaN            NaN         NaN       NaN       NaN
# 4             NaN            NaN         NaN       NaN       NaN
# 5             NaN            NaN         NaN       NaN       NaN
# 6             NaN            NaN         NaN       NaN       NaN
# 7             NaN            NaN         NaN       NaN       NaN
# 8             NaN            NaN         NaN       NaN       NaN
# 9               0              3        10.0       5.0      15.0
# 10              1              3        15.0       8.0      20.0
# 11              1              4        12.0       6.0      18.0
# 12              2              4        14.0       7.0      19.0
# 13              3              5        20.0      10.0      25.0
# 14              4              5        22.0      11.0      27.0
# 15              5              7        20.0      10.0      25.0
# 16              6              7        22.0      11.0      27.0
# 17              2              7        18.0       9.0      23.0
# 18              7              8        25.0      13.0      30.0

# %%
node_data_df
# Out:
#      cycle node_id  inventory  last_production
# 0        0       0          0               10
# 1        0       1          1               15
# 2        0       2          1               12
# 3        0       3          0               95
# 4        0       4          0              137
# ..     ...     ...        ...              ...
# 175     19       4          0               15
# 176     19       5          0               92
# 177     19       6          0                1
# 178     19       7          0              112
# 179     19       8        650              250
#
# [180 rows x 4 columns]

# %%
edge_data_df
# Out:
#      cycle edge_id  quantity  current_cost
# 0        0       0        30          15.0
# 1        0       1        35          14.0
# 2        0       2        30          12.0
# 3        0       3        32          13.0
# 4        0       4        40          17.5
# ..     ...     ...       ...           ...
# 195     19       5        31          27.0
# 196     19       6       147          17.5
# 197     19       7         1          27.0
# 198     19       8         7          16.0
# 199     19       9       289          13.0
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Conversion between JSON and DataFrames

# %%
from typing import Dict, List

def dataframes_to_json(metadata: pd.DataFrame, node: pd.DataFrame, edge: pd.DataFrame) -> str:
    bom = {
        "metadata": metadata.to_dict(orient='records'),
        "nodes": {},
        "edges": {}
    }

    # Process node data
    for _, row in node.iterrows():
        node_id = row['node_id']
        cycle = row['cycle']
        if node_id not in bom["nodes"]:
            bom["nodes"][node_id] = {}
        bom["nodes"][node_id][cycle] = row.to_dict()

    # Process edge data
    for _, row in edge.iterrows():
        edge_id = row['edge_id']
        cycle = row['cycle']
        if edge_id not in bom["edges"]:
            bom["edges"][edge_id] = {}
        bom["edges"][edge_id][cycle] = row.to_dict()

    return json.dumps(bom, indent=2)

def json_to_dataframes(json_data: str) -> Dict[str, pd.DataFrame]:
    bom = json.loads(json_data)

    # Create empty lists to store the data
    node_data = []
    edge_data = []

    # Process nodes
    for node_id, cycles in bom["nodes"].items():
        for cycle, node_info in cycles.items():
            node_data.append(node_info)

    # Process edges
    for edge_id, cycles in bom["edges"].items():
        for cycle, edge_info in cycles.items():
            edge_data.append(edge_info)

    # Create DataFrames
    metadata_df = pd.DataFrame(bom["metadata"])
    node_df = pd.DataFrame(node_data)
    edge_df = pd.DataFrame(edge_data)

    return {
        "metadata": metadata_df,
        "node": node_df,
        "edge": edge_df
    }

# %%
# Convert dataframes to JSON
json_string = dataframes_to_json(metadata_df, node_data_df, edge_data_df)

# %%
json_data = json.loads(json_string)
json_data
# Out:
# {'metadata': [{'node_id': '0',
#    'node_class': 'raw_material_1',
#    'max_inventory': 200.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '1',
#    'node_class': 'raw_material_2',
#    'max_inventory': 250.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '2',
#    'node_class': 'raw_material_3',
#    'max_inventory': 220.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '3',
#    'node_class': 'intermediate_a1',
#    'max_inventory': 300.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '4',
#    'node_class': 'intermediate_a2',
#    'max_inventory': 280.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '5',
#    'node_class': 'intermediate_b1',
#    'max_inventory': 300.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '6',
#    'node_class': 'intermediate_b2',
#    'max_inventory': 280.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '7',
#    'node_class': 'final_product',
#    'max_inventory': 350.0,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '8',
#    'node_class': 'sink',
#    'max_inventory': inf,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '0',
#    'source_node_id': '0',
#    'target_node_id': '3',
#    'unit_price': 10.0,
#    'min_cost': 5.0,
#    'max_cost': 15.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '1',
#    'source_node_id': '1',
#    'target_node_id': '3',
#    'unit_price': 15.0,
#    'min_cost': 8.0,
#    'max_cost': 20.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '2',
#    'source_node_id': '1',
#    'target_node_id': '4',
#    'unit_price': 12.0,
#    'min_cost': 6.0,
#    'max_cost': 18.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '3',
#    'source_node_id': '2',
#    'target_node_id': '4',
#    'unit_price': 14.0,
#    'min_cost': 7.0,
#    'max_cost': 19.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '4',
#    'source_node_id': '3',
#    'target_node_id': '5',
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '5',
#    'source_node_id': '4',
#    'target_node_id': '5',
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '6',
#    'source_node_id': '5',
#    'target_node_id': '7',
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '7',
#    'source_node_id': '6',
#    'target_node_id': '7',
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '8',
#    'source_node_id': '2',
#    'target_node_id': '7',
#    'unit_price': 18.0,
#    'min_cost': 9.0,
#    'max_cost': 23.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '9',
#    'source_node_id': '7',
#    'target_node_id': '8',
#    'unit_price': 25.0,
#    'min_cost': 13.0,
#    'max_cost': 30.0}],
#  'nodes': {'0': {'0': {'cycle': 0,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '1': {'cycle': 1, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '2': {'cycle': 2, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '3': {'cycle': 3, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '4': {'cycle': 4, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '5': {'cycle': 5, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '6': {'cycle': 6, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '7': {'cycle': 7, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '8': {'cycle': 8, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '9': {'cycle': 9, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '10': {'cycle': 10, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '11': {'cycle': 11, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '12': {'cycle': 12, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '13': {'cycle': 13, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '14': {'cycle': 14, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '15': {'cycle': 15, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '16': {'cycle': 16, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '17': {'cycle': 17, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '18': {'cycle': 18, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '19': {'cycle': 19, 'node_id': '0', 'inventory': 0, 'last_production': 10}},
#   '1': {'0': {'cycle': 0,
#     'node_id': '1',
#     'inventory': 1,
#     'last_production': 15},
#    '1': {'cycle': 1, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '2': {'cycle': 2, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '3': {'cycle': 3, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '4': {'cycle': 4, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '5': {'cycle': 5, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '6': {'cycle': 6, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '7': {'cycle': 7, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '8': {'cycle': 8, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '9': {'cycle': 9, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '10': {'cycle': 10, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '11': {'cycle': 11, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '12': {'cycle': 12, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '13': {'cycle': 13, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '14': {'cycle': 14, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '15': {'cycle': 15, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '16': {'cycle': 16, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '17': {'cycle': 17, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '18': {'cycle': 18, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '19': {'cycle': 19, 'node_id': '1', 'inventory': 1, 'last_production': 15}},
#   '2': {'0': {'cycle': 0,
#     'node_id': '2',
#     'inventory': 1,
#     'last_production': 12},
#    '1': {'cycle': 1, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '2': {'cycle': 2, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '3': {'cycle': 3, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '4': {'cycle': 4, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '5': {'cycle': 5, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '6': {'cycle': 6, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '7': {'cycle': 7, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '8': {'cycle': 8, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '9': {'cycle': 9, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '10': {'cycle': 10, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '11': {'cycle': 11, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '12': {'cycle': 12, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '13': {'cycle': 13, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '14': {'cycle': 14, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '15': {'cycle': 15, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '16': {'cycle': 16, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '17': {'cycle': 17, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '18': {'cycle': 18, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '19': {'cycle': 19, 'node_id': '2', 'inventory': 1, 'last_production': 12}},
#   '3': {'0': {'cycle': 0,
#     'node_id': '3',
#     'inventory': 0,
#     'last_production':

#     'node_id': '7',
#     'inventory': 0,
#     'last_production': 112}},
#   '8': {'0': {'cycle': 0,
#     'node_id': '8',
#     'inventory': 0,
#     'last_production': 50},
#    '1': {'cycle': 1, 'node_id': '8', 'inventory': 7, 'last_production': 250},
#    '2': {'cycle': 2, 'node_id': '8', 'inventory': 107, 'last_production': 250},
#    '3': {'cycle': 3, 'node_id': '8', 'inventory': 207, 'last_production': 250},
#    '4': {'cycle': 4, 'node_id': '8', 'inventory': 219, 'last_production': 250},
#    '5': {'cycle': 5, 'node_id': '8', 'inventory': 258, 'last_production': 250},
#    '6': {'cycle': 6, 'node_id': '8', 'inventory': 275, 'last_production': 250},
#    '7': {'cycle': 7, 'node_id': '8', 'inventory': 314, 'last_production': 250},
#    '8': {'cycle': 8, 'node_id': '8', 'inventory': 331, 'last_production': 250},
#    '9': {'cycle': 9, 'node_id': '8', 'inventory': 370, 'last_production': 250},
#    '10': {'cycle': 10,
#     'node_id': '8',
#     'inventory': 387,
#     'last_production': 250},
#    '11': {'cycle': 11,
#     'node_id': '8',
#     'inventory': 426,
#     'last_production': 250},
#    '12': {'cycle': 12,
#     'node_id': '8',
#     'inventory': 443,
#     'last_production': 250},
#    '13': {'cycle': 13,
#     'node_id': '8',
#     'inventory': 482,
#     'last_production': 250},
#    '14': {'cycle': 14,
#     'node_id': '8',
#     'inventory': 499,
#     'last_production': 250},
#    '15': {'cycle': 15,
#     'node_id': '8',
#     'inventory': 538,
#     'last_production': 250},
#    '16': {'cycle': 16,
#     'node_id': '8',
#     'inventory': 555,
#     'last_production': 250},
#    '17': {'cycle': 17,
#     'node_id': '8',
#     'inventory': 594,
#     'last_production': 250},
#    '18': {'cycle': 18,
#     'node_id': '8',
#     'inventory': 611,
#     'last_production': 250},
#    '19': {'cycle': 19,
#     'node_id': '8',
#     'inventory': 650,
#     'last_production': 250}}},
#  'edges': {'0': {'0': {'cycle': 0,
#     'edge_id': '0',
#     'quantity': 30,
#     'current_cost': 15.0},
#    '1': {'cycle': 1, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '2': {'cycle': 2, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '3': {'cycle': 3, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '4': {'cycle': 4, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '5': {'cycle': 5, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '6': {'cycle': 6, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '7': {'cycle': 7, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '8': {'cycle': 8, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '9': {'cycle': 9, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '10': {'cycle': 10, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '11': {'cycle': 11, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '12': {'cycle': 12, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '13': {'cycle': 13, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '14': {'cycle': 14, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '15': {'cycle': 15, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '16': {'cycle': 16, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '17': {'cycle': 17, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '18': {'cycle': 18, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0},
#    '19': {'cycle': 19, 'edge_id': '0', 'quantity': 10, 'current_cost': 15.0}},
#   '1': {'0': {'cycle': 0,
#     'edge_id': '1',
#     'quantity': 35,
#     'current_cost': 14.0},
#    '1': {'cycle': 1, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '2': {'cycle': 2, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '3': {'cycle': 3, 'edge_id': '1', 'quantity': 9, 'current_cost': 14.0},
#    '4': {'cycle': 4, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '5': {'cycle': 5, 'edge_id': '1', 'quantity': 9, 'current_cost': 14.0},
#    '6': {'cycle': 6, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '7': {'cycle': 7, 'edge_id': '1', 'quantity': 9, 'current_cost': 14.0},
#    '8': {'cycle': 8, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '9': {'cycle': 9, 'edge_id': '1', 'quantity': 9, 'current_cost': 14.0},
#    '10': {'cycle': 10, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '11': {'cycle': 11, 'edge_id': '1', 'quantity': 9, 'current_cost': 14.0},
#    '12': {'cycle': 12, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '13': {'cycle': 13, 'edge_id': '1', 'quantity': 9, 'current_cost': 14.0},
#    '14': {'cycle': 14, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '15': {'cycle': 15, 'edge_id': '1', 'quantity': 9, 'current_cost': 14.0},
#    '16': {'cycle': 16, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '17': {'cycle': 17, 'edge_id': '1', 'quantity': 9, 'current_cost': 14.0},
#    '18': {'cycle': 18, 'edge_id': '1', 'quantity': 8, 'current_cost': 14.0},
#    '19': {'cycle': 19, 'edge_id': '1', 'quantity': 9, 'current_cost': 14.0}},
#   '2': {'0': {'cycle': 0,
#     'edge_id': '2',
#     'quantity': 30,
#     'current_cost': 12.0},
#    '1': {'cycle': 1, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0},
#    '2': {'cycle': 2, 'edge_id': '2', 'quantity': 7, 'current_cost': 12.0},
#    '3': {'cycle': 3, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0},
#    '4': {'cycle': 4, 'edge_id': '2', 'quantity': 7, 'current_cost': 12.0},
#    '5': {'cycle': 5, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0},
#    '6': {'cycle': 6, 'edge_id': '2', 'quantity': 7, 'current_cost': 12.0},
#    '7': {'cycle': 7, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0},
#    '8': {'cycle': 8, 'edge_id': '2', 'quantity': 7, 'current_cost': 12.0},
#    '9': {'cycle': 9, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0},
#    '10': {'cycle': 10, 'edge_id': '2', 'quantity': 7, 'current_cost': 12.0},
#    '11': {'cycle': 11, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0},
#    '12': {'cycle': 12, 'edge_id': '2', 'quantity': 7, 'current_cost': 12.0},
#    '13': {'cycle': 13, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0},
#    '14': {'cycle': 14, 'edge_id': '2', 'quantity': 7, 'current_cost': 12.0},
#    '15': {'cycle': 15, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0},
#    '16': {'cycle': 16, 'edge_id': '2', 'quantity': 7, 'current_cost': 12.0},
#    '17': {'cycle': 17, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0},
#    '18': {'cycle': 18, 'edge_id': '2', 'quantity': 7, 'current_cost': 12.0},
#    '19': {'cycle': 19, 'edge_id': '2', 'quantity': 6, 'current_cost': 12.0}},
#   '3': {'0': {'cycle': 0,
#     'edge_id': '3',
#     'quantity': 32,
#     'current_cost': 13.0},
#    '1': {'cycle': 1, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0},
#    '2': {'cycle': 2, 'edge_id': '3', 'quantity': 6, 'current_cost': 13.0},
#    '3': {'cycle': 3, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0},
#    '4': {'cycle': 4, 'edge_id': '3', 'quantity': 6, 'current_cost': 13.0},
#    '5': {'cycle': 5, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0},
#    '6': {'cycle': 6, 'edge_id': '3', 'quantity': 6, 'current_cost': 13.0},
#    '7': {'cycle': 7, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0},
#    '8': {'cycle': 8, 'edge_id': '3', 'quantity': 6, 'current_cost': 13.0},
#    '9': {'cycle': 9, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0},
#    '10': {'cycle': 10, 'edge_id': '3', 'quantity': 6, 'current_cost': 13.0},
#    '11': {'cycle': 11, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0},
#    '12': {'cycle': 12, 'edge_id': '3', 'quantity': 6, 'current_cost': 13.0},
#    '13': {'cycle': 13, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0},
#    '14': {'cycle': 14, 'edge_id': '3', 'quantity': 6, 'current_cost': 13.0},
#    '15': {'cycle': 15, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0},
#    '16': {'cycle': 16, 'edge_id': '3', 'quantity': 6, 'current_cost': 13.0},
#    '17': {'cycle': 17, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0},
#    '18': {'cycle': 18, 'edge_id': '3', 'quantity': 6, 'current_cost': 13.0},
#    '19': {'cycle': 19, 'edge_id': '3', 'quantity': 5, 'current_cost': 13.0}},
#   '4': {'0': {'cycle': 0,
#     'edge_id': '4',
#     'quantity': 40,
#     'current_cost': 17.5},
#    '1': {'cycle': 1, 'edge_id': '4', 'quantity': 160, 'current_cost': 17.5},
#    '2': {'cycle': 2, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5},
#    '3': {'cycle': 3, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5},
#    '4': {'cycle': 4, 'edge_id': '4', 'quantity': 40, 'current_cost': 17.5},
#    '5': {'cycle': 5, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5},
#    '6': {'cycle': 6, 'edge_id': '4', 'quantity': 40, 'current_cost': 17.5},
#    '7': {'cycle': 7, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5},
#    '8': {'cycle': 8, 'edge_id': '4', 'quantity': 40, 'current_cost': 17.5},
#    '9': {'cycle': 9, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5},
#    '10': {'cycle': 10, 'edge_id': '4', 'quantity': 40, 'current_cost': 17.5},
#    '11': {'cycle': 11, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5},
#    '12': {'cycle': 12, 'edge_id': '4', 'quantity': 40, 'current_cost': 17.5},
#    '13': {'cycle': 13, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5},
#    '14': {'cycle': 14, 'edge_id': '4', 'quantity': 40, 'current_cost': 17.5},
#    '15': {'cycle': 15, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5},
#    '16': {'cycle': 16, 'edge_id': '4', 'quantity': 40, 'current_cost': 17.5},
#    '17': {'cycle': 17, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5},
#    '18': {'cycle': 18, 'edge_id': '4', 'quantity': 40, 'current_cost': 17.5},
#    '19': {'cycle': 19, 'edge_id': '4', 'quantity': 38, 'current_cost': 17.5}},
#   '5': {'0': {'cycle': 0,
#     'edge_id': '5',
#     'quantity': 42,
#     'current_cost': 27.0},
#    '1': {'cycle': 1, 'edge_id': '5', 'quantity': 199, 'current_cost': 27.0},
#    '2': {'cycle': 2, 'edge_id': '5', 'quantity': 26, 'current_cost': 27.0},
#    '3': {'cycle': 3, 'edge_id': '5', 'quantity': 31, 'current_cost': 27.0},
#    '4': {'cycle': 4, 'edge_id': '5', 'quantity': 26, 'current_cost': 27.0},
#    '5': {'cycle': 5, 'edge_id': '5', 'quantity': 31, 'current_cost': 27.0},
#    '6': {'cycle': 6, 'edge_id': '5', 'quantity': 26, 'current_cost': 27.0},
#    '7': {'cycle': 7, 'edge_id': '5', 'quantity': 31, 'current_cost': 27.0},
#    '8': {'cycle': 8, 'edge_id': '5', 'quantity': 26, 'current_cost': 27.0},
#    '9': {'cycle': 9, 'edge_id': '5', 'quantity': 31, 'current_cost': 27.0},
#    '10': {'cycle': 10, 'edge_id': '5', 'quantity': 26, 'current_cost': 27.0},
#    '11': {'cycle': 11, 'edge_id': '5', 'quantity': 31, 'current_cost': 27.0},
#    '12': {'cycle': 12, 'edge_id': '5', 'quantity': 26, 'current_cost': 27.0},
#    '13': {'cycle': 13, 'edge_id': '5', 'quantity': 31, 'current_cost': 27.0},
#    '14': {'cycle': 14, 'edge_id': '5', 'quantity': 26, 'current_cost': 27.0},
#    '15': {'cycle': 15, 'edge_id': '5', 'quantity': 31, 'current_cost': 27.0},
#    '16': {'cycle': 16, 'edge_id': '5', 'quantity': 26, 'current_cost': 27.0},
#    '17': {'cycle': 17, 'edge_id': '5', 'quantity': 31, 'current_cost': 27.0},
#    '18': {'cycle': 18, 'edge_id': '5', 'quantity': 26, 'current_cost': 27.0},
#    '19': {'cycle': 19, 'edge_id': '5', 'quantity': 31, 'current_cost': 27.0}},
#   '6': {'0': {'cycle': 0,
#     'edge_id': '6',
#     'quantity': 40,
#     'current_cost': 17.5},
#    '1': {'cycle': 1, 'edge_id': '6', 'quantity': 202, 'current_cost': 17.5},
#    '2': {'cycle': 2, 'edge_id': '6', 'quantity': 300, 'current_cost': 17.5},
#    '3': {'cycle': 3, 'edge_id': '6', 'quantity': 144, 'current_cost': 17.5},
#    '4': {'cycle': 4, 'edge_id': '6', 'quantity': 161, 'current_cost': 17.5},
#    '5': {'cycle': 5, 'edge_id': '6', 'quantity': 147, 'current_cost': 17.5},
#    '6': {'cycle': 6, 'edge_id': '6', 'quantity': 161, 'current_cost': 17.5},
#    '7': {'cycle': 7, 'edge_id': '6', 'quantity': 147, 'current_cost': 17.5},
#    '8': {'cycle': 8, 'edge_id': '6', 'quantity': 161, 'current_cost': 17.5},
#    '9': {'cycle': 9, 'edge_id': '6', 'quantity': 147, 'current_cost': 17.5},
#    '10': {'cycle': 10, 'edge_id': '6', 'quantity': 161, 'current_cost': 17.5},
#    '11': {'cycle': 11, 'edge_id': '6', 'quantity': 147, 'current_cost': 17.5},
#    '12': {'cycle': 12, 'edge_id': '6', 'quantity': 161, 'current_cost': 17.5},
#    '13': {'cycle': 13, 'edge_id': '6', 'quantity': 147, 'current_cost': 17.5},
#    '14': {'cycle': 14, 'edge_id': '6', 'quantity': 161, 'current_cost': 17.5},
#    '15': {'cycle': 15, 'edge_id': '6', 'quantity': 147, 'current_cost': 17.5},
#    '16': {'cycle': 16, 'edge_id': '6', 'quantity': 161, 'current_cost': 17.5},
#    '17': {'cycle': 17, 'edge_id': '6', 'quantity': 147, 'current_cost': 17.5},
#    '18': {'cycle': 18, 'edge_id': '6', 'quantity': 161, 'current_cost': 17.5},
#    '19': {'cycle': 19, 'edge_id': '6', 'quantity': 147, 'current_cost': 17.5}},
#   '7': {'0': {'cycle': 0,
#     'edge_id': '7',
#     'quantity': 42,
#     'current_cost': 27.0},
#    '1': {'cycle': 1, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '2': {'cycle': 2, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '3': {'cycle': 3, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '4': {'cycle': 4, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '5': {'cycle': 5, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '6': {'cycle': 6, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '7': {'cycle': 7, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '8': {'cycle': 8, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '9': {'cycle': 9, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '10': {'cycle': 10, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '11': {'cycle': 11, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '12': {'cycle': 12, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '13': {'cycle': 13, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '14': {'cycle': 14, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '15': {'cycle': 15, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '16': {'cycle': 16, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '17': {'cycle': 17, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '18': {'cycle': 18, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0},
#    '19': {'cycle': 19, 'edge_id': '7', 'quantity': 1, 'current_cost': 27.0}},
#   '8': {'0': {'cycle': 0,
#     'edge_id': '8',
#     'quantity': 35,
#     'current_cost': 16.0},
#    '1': {'cycle': 1, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '2': {'cycle': 2, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '3': {'cycle': 3, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '4': {'cycle': 4, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '5': {'cycle': 5, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '6': {'cycle': 6, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '7': {'cycle': 7, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '8': {'cycle': 8, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '9': {'cycle': 9, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '10': {'cycle': 10, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '11': {'cycle': 11, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '12': {'cycle': 12, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '13': {'cycle': 13, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '14': {'cycle': 14, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '15': {'cycle': 15, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '16': {'cycle': 16, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '17': {'cycle': 17, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '18': {'cycle': 18, 'edge_id': '8', 'quantity': 6, 'current_cost': 16.0},
#    '19': {'cycle': 19, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0}},
#   '9': {'0': {'cycle': 0,
#     'edge_id': '9',
#     'quantity': 50,
#     'current_cost': 13.0},
#    '1': {'cycle': 1, 'edge_id': '9', 'quantity': 257, 'current_cost': 13.0},
#    '2': {'cycle': 2, 'edge_id': '9', 'quantity': 350, 'current_cost': 13.0},
#    '3': {'cycle': 3, 'edge_id': '9', 'quantity': 350, 'current_cost': 13.0},
#    '4': {'cycle': 4, 'edge_id': '9', 'quantity': 262, 'current_cost': 13.0},
#    '5': {'cycle': 5, 'edge_id': '9', 'quantity': 289, 'current_cost': 13.0},
#    '6': {'cycle': 6, 'edge_id': '9', 'quantity': 267, 'current_cost': 13.0},
#    '7': {'cycle': 7, 'edge_id': '9', 'quantity': 289, 'current_cost': 13.0},
#    '8': {'cycle': 8, 'edge_id': '9', 'quantity': 267, 'current_cost': 13.0},
#    '9': {'cycle': 9, 'edge_id': '9', 'quantity': 289, 'current_cost': 13.0},
#    '10': {'cycle': 10, 'edge_id': '9', 'quantity': 267, 'current_cost': 13.0},
#    '11': {'cycle': 11, 'edge_id': '9', 'quantity': 289, 'current_cost': 13.0},
#    '12': {'cycle': 12, 'edge_id': '9', 'quantity': 267, 'current_cost': 13.0},
#    '13': {'cycle': 13, 'edge_id': '9', 'quantity': 289, 'current_cost': 13.0},
#    '14': {'cycle': 14, 'edge_id': '9', 'quantity': 267, 'current_cost': 13.0},
#    '15': {'cycle': 15, 'edge_id': '9', 'quantity': 289, 'current_cost': 13.0},
#    '16': {'cycle': 16, 'edge_id': '9', 'quantity': 267, 'current_cost': 13.0},
#    '17': {'cycle': 17, 'edge_id': '9', 'quantity': 289, 'current_cost': 13.0},
#    '18': {'cycle': 18, 'edge_id': '9', 'quantity': 267, 'current_cost': 13.0},
#    '19': {'cycle': 19,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0}}}}

# %%
if SAVE_RECORDS:
    with open('../data/json/true.json', 'w') as f:
        json.dump(json_data, f, ensure_ascii=False)

# %%
# Convert JSON back to dataframes
reconstructed_dfs = json_to_dataframes(json_string)

# Access the reconstructed dataframes
reconstructed_metadata = reconstructed_dfs['metadata']
reconstructed_node = reconstructed_dfs['node']
reconstructed_edge = reconstructed_dfs['edge']

# %%
if SAVE_RECORDS:
    reconstructed_metadata.to_csv('../data/csv/metadata.csv', index=False)
    reconstructed_node.to_csv('../data/csv/node.csv', index=False)
    reconstructed_edge.to_csv('../data/csv/edge.csv', index=False)

# %%
reconstructed_metadata
# Out:
#    node_id       node_class  max_inventory         cost_type edge_id  \
# 0        0   raw_material_1          200.0  negative_dynamic     NaN
# 1        1   raw_material_2          250.0             fixed     NaN
# 2        2   raw_material_3          220.0             fixed     NaN
# 3        3  intermediate_a1          300.0             fixed     NaN
# 4        4  intermediate_a2          280.0  negative_dynamic     NaN
# 5        5  intermediate_b1          300.0             fixed     NaN
# 6        6  intermediate_b2          280.0  negative_dynamic     NaN
# 7        7    final_product          350.0  positive_dynamic     NaN
# 8        8             sink            inf  positive_dynamic     NaN
# 9      NaN              NaN            NaN               NaN       0
# 10     NaN              NaN            NaN               NaN       1
# 11     NaN              NaN            NaN               NaN       2
# 12     NaN              NaN            NaN               NaN       3
# 13     NaN              NaN            NaN               NaN       4
# 14     NaN              NaN            NaN               NaN       5
# 15     NaN              NaN            NaN               NaN       6
# 16     NaN              NaN            NaN               NaN       7
# 17     NaN              NaN            NaN               NaN       8
# 18     NaN              NaN            NaN               NaN       9
#
#    source_node_id target_node_id  unit_price  min_cost  max_cost
# 0             NaN            NaN         NaN       NaN       NaN
# 1             NaN            NaN         NaN       NaN       NaN
# 2             NaN            NaN         NaN       NaN       NaN
# 3             NaN            NaN         NaN       NaN       NaN
# 4             NaN            NaN         NaN       NaN       NaN
# 5             NaN            NaN         NaN       NaN       NaN
# 6             NaN            NaN         NaN       NaN       NaN
# 7             NaN            NaN         NaN       NaN       NaN
# 8             NaN            NaN         NaN       NaN       NaN
# 9               0              3        10.0       5.0      15.0
# 10              1              3        15.0       8.0      20.0
# 11              1              4        12.0       6.0      18.0
# 12              2              4        14.0       7.0      19.0
# 13              3              5        20.0      10.0      25.0
# 14              4              5        22.0      11.0      27.0
# 15              5              7        20.0      10.0      25.0
# 16              6              7        22.0      11.0      27.0
# 17              2              7        18.0       9.0      23.0
# 18              7              8        25.0      13.0      30.0

# %%
reconstructed_node
# Out:
#      cycle node_id  inventory  last_production
# 0        0       0          0               10
# 1        1       0          0               10
# 2        2       0          0               10
# 3        3       0          0               10
# 4        4       0          0               10
# ..     ...     ...        ...              ...
# 175     15       8        538              250
# 176     16       8        555              250
# 177     17       8        594              250
# 178     18       8        611              250
# 179     19       8        650              250
#
# [180 rows x 4 columns]

# %%
reconstructed_edge
# Out:
#      cycle edge_id  quantity  current_cost
# 0        0       0        30          15.0
# 1        1       0        10          15.0
# 2        2       0        10          15.0
# 3        3       0        10          15.0
# 4        4       0        10          15.0
# ..     ...     ...       ...           ...
# 195     15       9       289          13.0
# 196     16       9       267          13.0
# 197     17       9       289          13.0
# 198     18       9       267          13.0
# 199     19       9       289          13.0
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Aggredation of Cycles and Conversion between JSON and Dataframes

# %%
from typing import Dict

def aggregated_dataframes_to_json(metadata: pd.DataFrame, node: pd.DataFrame, edge: pd.DataFrame, max_aggregation_cycles: int = 3) -> str:
    bom = {
        "metadata": metadata.to_dict(orient='records'),
        "nodes": {},
        "edges": {}
    }

    # Initialize variables to track the last cycle
    last_node_cycle = 0
    last_edge_cycle = 0
    
    num_cycles_to_aggregate = random.randint(1, max_aggregation_cycles)

    # Process node data with aggregation
    for _, row in node.iterrows():
        node_id = row['node_id']
        cycle = row['cycle']
        # Check if we can aggregate
        if node_id not in bom["nodes"]:
            bom["nodes"][node_id] = {}
        
        # Aggregate nodes
        for _ in range(num_cycles_to_aggregate):
            last_node_cycle += 1
            # Create a new entry for the aggregated node
            aggregated_node = row.copy()
            aggregated_node['cycle'] = last_node_cycle
            bom["nodes"][node_id][last_node_cycle] = aggregated_node.to_dict()

    # Process edge data with aggregation
    for _, row in edge.iterrows():
        edge_id = row['edge_id']
        cycle = row['cycle']
        # Check if we can aggregate
        if edge_id not in bom["edges"]:
            bom["edges"][edge_id] = {}
        
        # Aggregate edges
        for _ in range(num_cycles_to_aggregate):
            last_edge_cycle += 1
            # Create a new entry for the aggregated edge
            aggregated_edge = row.copy()
            aggregated_edge['cycle'] = last_edge_cycle
            bom["edges"][edge_id][last_edge_cycle] = aggregated_edge.to_dict()

    return json.dumps(bom, indent=2)

# %%
aggregated_json = aggregated_dataframes_to_json(metadata_df, node_data_df, edge_data_df)
aggregated_json_dict = json.loads(aggregated_json)

aggregated_json_dict
# Out:
# {'metadata': [{'node_id': '0',
#    'node_class': 'raw_material_1',
#    'max_inventory': 200.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '1',
#    'node_class': 'raw_material_2',
#    'max_inventory': 250.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '2',
#    'node_class': 'raw_material_3',
#    'max_inventory': 220.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '3',
#    'node_class': 'intermediate_a1',
#    'max_inventory': 300.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '4',
#    'node_class': 'intermediate_a2',
#    'max_inventory': 280.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '5',
#    'node_class': 'intermediate_b1',
#    'max_inventory': 300.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '6',
#    'node_class': 'intermediate_b2',
#    'max_inventory': 280.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '7',
#    'node_class': 'final_product',
#    'max_inventory': 350.0,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '8',
#    'node_class': 'sink',
#    'max_inventory': inf,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '0',
#    'source_node_id': '0',
#    'target_node_id': '3',
#    'unit_price': 10.0,
#    'min_cost': 5.0,
#    'max_cost': 15.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '1',
#    'source_node_id': '1',
#    'target_node_id': '3',
#    'unit_price': 15.0,
#    'min_cost': 8.0,
#    'max_cost': 20.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '2',
#    'source_node_id': '1',
#    'target_node_id': '4',
#    'unit_price': 12.0,
#    'min_cost': 6.0,
#    'max_cost': 18.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '3',
#    'source_node_id': '2',
#    'target_node_id': '4',
#    'unit_price': 14.0,
#    'min_cost': 7.0,
#    'max_cost': 19.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '4',
#    'source_node_id': '3',
#    'target_node_id': '5',
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '5',
#    'source_node_id': '4',
#    'target_node_id': '5',
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '6',
#    'source_node_id': '5',
#    'target_node_id': '7',
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '7',
#    'source_node_id': '6',
#    'target_node_id': '7',
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '8',
#    'source_node_id': '2',
#    'target_node_id': '7',
#    'unit_price': 18.0,
#    'min_cost': 9.0,
#    'max_cost': 23.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '9',
#    'source_node_id': '7',
#    'target_node_id': '8',
#    'unit_price': 25.0,
#    'min_cost': 13.0,
#    'max_cost': 30.0}],
#  'nodes': {'0': {'1': {'cycle': 1,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '2': {'cycle': 2, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '3': {'cycle': 3, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '28': {'cycle': 28, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '29': {'cycle': 29, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '30': {'cycle': 30, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '55': {'cycle': 55, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '56': {'cycle': 56, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '57': {'cycle': 57, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '82': {'cycle': 82, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '83': {'cycle': 83, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '84': {'cycle': 84, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '109': {'cycle': 109,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '110': {'cycle': 110,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '111': {'cycle': 111,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '136': {'cycle': 136,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '137': {'cycle': 137,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '138': {'cycle': 138,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    
 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '596': {'cycle': 596, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0},
#    '597': {'cycle': 597, 'edge_id': '8', 'quantity': 7, 'current_cost': 16.0}},
#   '9': {'28': {'cycle': 28,
#     'edge_id': '9',
#     'quantity': 50,
#     'current_cost': 13.0},
#    '29': {'cycle': 29, 'edge_id': '9', 'quantity': 50, 'current_cost': 13.0},
#    '30': {'cycle': 30, 'edge_id': '9', 'quantity': 50, 'current_cost': 13.0},
#    '58': {'cycle': 58, 'edge_id': '9', 'quantity': 257, 'current_cost': 13.0},
#    '59': {'cycle': 59, 'edge_id': '9', 'quantity': 257, 'current_cost': 13.0},
#    '60': {'cycle': 60, 'edge_id': '9', 'quantity': 257, 'current_cost': 13.0},
#    '88': {'cycle': 88, 'edge_id': '9', 'quantity': 350, 'current_cost': 13.0},
#    '89': {'cycle': 89, 'edge_id': '9', 'quantity': 350, 'current_cost': 13.0},
#    '90': {'cycle': 90, 'edge_id': '9', 'quantity': 350, 'current_cost': 13.0},
#    '118': {'cycle': 118,
#     'edge_id': '9',
#     'quantity': 350,
#     'current_cost': 13.0},
#    '119': {'cycle': 119,
#     'edge_id': '9',
#     'quantity': 350,
#     'current_cost': 13.0},
#    '120': {'cycle': 120,
#     'edge_id': '9',
#     'quantity': 350,
#     'current_cost': 13.0},
#    '148': {'cycle': 148,
#     'edge_id': '9',
#     'quantity': 262,
#     'current_cost': 13.0},
#    '149': {'cycle': 149,
#     'edge_id': '9',
#     'quantity': 262,
#     'current_cost': 13.0},
#    '150': {'cycle': 150,
#     'edge_id': '9',
#     'quantity': 262,
#     'current_cost': 13.0},
#    '178': {'cycle': 178,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '179': {'cycle': 179,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '180': {'cycle': 180,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '208': {'cycle': 208,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '209': {'cycle': 209,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '210': {'cycle': 210,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '238': {'cycle': 238,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '239': {'cycle': 239,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '240': {'cycle': 240,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '268': {'cycle': 268,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '269': {'cycle': 269,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '270': {'cycle': 270,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '298': {'cycle': 298,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '299': {'cycle': 299,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '300': {'cycle': 300,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '328': {'cycle': 328,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '329': {'cycle': 329,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '330': {'cycle': 330,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '358': {'cycle': 358,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '359': {'cycle': 359,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '360': {'cycle': 360,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '388': {'cycle': 388,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '389': {'cycle': 389,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '390': {'cycle': 390,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '418': {'cycle': 418,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '419': {'cycle': 419,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '420': {'cycle': 420,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '448': {'cycle': 448,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '449': {'cycle': 449,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '450': {'cycle': 450,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '478': {'cycle': 478,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '479': {'cycle': 479,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '480': {'cycle': 480,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '508': {'cycle': 508,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '509': {'cycle': 509,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '510': {'cycle': 510,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '538': {'cycle': 538,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '539': {'cycle': 539,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '540': {'cycle': 540,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '568': {'cycle': 568,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '569': {'cycle': 569,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '570': {'cycle': 570,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 13.0},
#    '598': {'cycle': 598,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '599': {'cycle': 599,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0},
#    '600': {'cycle': 600,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 13.0}}}}

# %%
if SAVE_RECORDS:
    import json
    with open('../data/json/aggregated.json', 'w') as f:
        json.dump(aggregated_json_dict, f, ensure_ascii=False)

# %%
aggregated_dataframe = json_to_dataframes(aggregated_json)

aggregated_metadata = aggregated_dataframe["metadata"]
aggregated_nodes = aggregated_dataframe["node"]
aggregated_edges = aggregated_dataframe["edge"]

# %%
if SAVE_RECORDS:
    aggregated_metadata.to_csv("../data/csv/aggregated_metadata.csv", index=False)
    aggregated_nodes.to_csv("../data/csv/aggregated_node_data.csv", index=False)
    aggregated_edges.to_csv("../data/csv/aggregated_edge_data.csv", index=False)

# %%
aggregated_metadata
# Out:
#    node_id       node_class  max_inventory         cost_type edge_id  \
# 0        0   raw_material_1          200.0  negative_dynamic     NaN
# 1        1   raw_material_2          250.0             fixed     NaN
# 2        2   raw_material_3          220.0             fixed     NaN
# 3        3  intermediate_a1          300.0             fixed     NaN
# 4        4  intermediate_a2          280.0  negative_dynamic     NaN
# 5        5  intermediate_b1          300.0             fixed     NaN
# 6        6  intermediate_b2          280.0  negative_dynamic     NaN
# 7        7    final_product          350.0  positive_dynamic     NaN
# 8        8             sink            inf  positive_dynamic     NaN
# 9      NaN              NaN            NaN               NaN       0
# 10     NaN              NaN            NaN               NaN       1
# 11     NaN              NaN            NaN               NaN       2
# 12     NaN              NaN            NaN               NaN       3
# 13     NaN              NaN            NaN               NaN       4
# 14     NaN              NaN            NaN               NaN       5
# 15     NaN              NaN            NaN               NaN       6
# 16     NaN              NaN            NaN               NaN       7
# 17     NaN              NaN            NaN               NaN       8
# 18     NaN              NaN            NaN               NaN       9
#
#    source_node_id target_node_id  unit_price  min_cost  max_cost
# 0             NaN            NaN         NaN       NaN       NaN
# 1             NaN            NaN         NaN       NaN       NaN
# 2             NaN            NaN         NaN       NaN       NaN
# 3             NaN            NaN         NaN       NaN       NaN
# 4             NaN            NaN         NaN       NaN       NaN
# 5             NaN            NaN         NaN       NaN       NaN
# 6             NaN            NaN         NaN       NaN       NaN
# 7             NaN            NaN         NaN       NaN       NaN
# 8             NaN            NaN         NaN       NaN       NaN
# 9               0              3        10.0       5.0      15.0
# 10              1              3        15.0       8.0      20.0
# 11              1              4        12.0       6.0      18.0
# 12              2              4        14.0       7.0      19.0
# 13              3              5        20.0      10.0      25.0
# 14              4              5        22.0      11.0      27.0
# 15              5              7        20.0      10.0      25.0
# 16              6              7        22.0      11.0      27.0
# 17              2              7        18.0       9.0      23.0
# 18              7              8        25.0      13.0      30.0

# %%
aggregated_nodes
# Out:
#      cycle node_id  inventory  last_production
# 0        1       0          0               10
# 1        2       0          0               10
# 2        3       0          0               10
# 3       28       0          0               10
# 4       29       0          0               10
# ..     ...     ...        ...              ...
# 535    512       8        611              250
# 536    513       8        611              250
# 537    538       8        650              250
# 538    539       8        650              250
# 539    540       8        650              250
#
# [540 rows x 4 columns]

# %%
aggregated_edges
# Out:
#      cycle edge_id  quantity  current_cost
# 0        1       0        30          15.0
# 1        2       0        30          15.0
# 2        3       0        30          15.0
# 3       31       0        10          15.0
# 4       32       0        10          15.0
# ..     ...     ...       ...           ...
# 595    569       9       267          13.0
# 596    570       9       267          13.0
# 597    598       9       289          13.0
# 598    599       9       289          13.0
# 599    600       9       289          13.0
#
# [600 rows x 4 columns]
