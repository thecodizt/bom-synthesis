# %% [markdown]
# # Generation of BoM Data for Supply Chain Simulation

# %%
SAVE_RECORDS=True

# %% [markdown]
# ## Supply Chain Simulation

# %%
import numpy as np
from scipy import interpolate
import math
import random

class Edge:
    def __init__(self, unit_price, min_cost, max_cost):
        self.unit_price = unit_price
        self.in_transit = [0, 0, 0]  # 3 cycles of transit
        self.quantity = 0  # Current cycle's quantity
        self.min_cost = min_cost
        self.max_cost = max_cost
        self.current_cost = 0

    def update(self, new_quantity):
        delivered = self.in_transit.pop(0)
        self.in_transit.append(new_quantity)
        self.quantity = delivered
        return delivered

    def initialize(self, initial_quantity):
        self.in_transit = [initial_quantity] * 3
        self.quantity = initial_quantity

    def calculate_cost(self, source_node):
        if source_node.cost_type == "fixed":
            self.current_cost = (self.min_cost + self.max_cost) / 2
        elif source_node.cost_type == "positive_dynamic":
            cost_range = self.max_cost - self.min_cost
            inventory_ratio = source_node.inventory / source_node.max_inventory
            self.current_cost = self.min_cost + (cost_range * inventory_ratio)
        elif source_node.cost_type == "negative_dynamic":
            cost_range = self.max_cost - self.min_cost
            inventory_ratio = 1 - (source_node.inventory / source_node.max_inventory)
            self.current_cost = self.min_cost + (cost_range * inventory_ratio)
        return self.current_cost * self.quantity

class Node:
    def __init__(self, max_inventory, node_class, cost_type):
        self.max_inventory = max_inventory
        self.inventory = 0
        self.node_class = node_class
        self.incoming_edges = []
        self.outgoing_edges = []
        self.last_production = 0
        self.cost_type = cost_type

    def add_incoming_edge(self, edge, source_node):
        self.incoming_edges.append((edge, source_node))

    def add_outgoing_edge(self, edge, target_node):
        self.outgoing_edges.append((edge, target_node))

    def update(self):
        self.receive()
        self.produce()
        self.distribute()

    def receive(self):
        for edge, _ in self.incoming_edges:
            self.inventory = min(self.max_inventory, self.inventory + edge.update(0))

    def produce(self):
        production = min(self.calculate_production(), self.max_inventory - self.inventory)
        self.inventory = min(self.max_inventory, self.inventory + production)
        self.last_production = production

    def distribute(self):
        if not self.outgoing_edges:
            return
        total_demand = sum(edge.quantity for edge, _ in self.outgoing_edges)
        if total_demand == 0:
            total_demand = len(self.outgoing_edges)  # Distribute evenly if no demand
        available = max(self.inventory, self.last_production)  # Always distribute something
        ratio = available / total_demand
        for edge, target_node in self.outgoing_edges:
            amount = max(1, int(edge.quantity * ratio))  # Always send at least 1
            self.inventory = max(0, self.inventory - amount)
            edge.update(amount)
            edge.calculate_cost(self)

    def calculate_production(self):
        raise NotImplementedError("Subclasses must implement calculate_production method")

class LeafNode(Node):
    def __init__(self, max_inventory, node_class, spline_points, cost_type):
        super().__init__(max_inventory, node_class, cost_type)
        x, y = zip(*spline_points)
        self.spline = interpolate.interp1d(x, y, kind='linear', fill_value='extrapolate')

    def calculate_production(self):
        return max(0, int(self.spline(time)))

class CombinerNode(Node):
    def __init__(self, max_inventory, node_class, a_coeffs, b_powers, cost_type):
        super().__init__(max_inventory, node_class, cost_type)
        self.a_coeffs = a_coeffs
        self.b_powers = b_powers

    def calculate_production(self):
        production = 0
        for (edge, _), a, b in zip(self.incoming_edges, self.a_coeffs, self.b_powers):
            production += a * (max(1, edge.quantity) ** b)  # Always use at least 1
        return max(1, int(production))  # Always produce at least 1

class SinkNode(Node):
    def __init__(self, consumption_rate, cost_type):
        super().__init__(math.inf, "sink", cost_type)
        self.consumption_rate = consumption_rate
        self.total_consumed = 0

    def update(self):
        self.receive()
        self.consume()

    def consume(self):
        consumed = min(self.inventory, self.consumption_rate)
        self.inventory -= consumed
        self.total_consumed += consumed
        self.last_production = consumed  # For consistency in reporting

    def calculate_production(self):
        return 0  # Sink nodes don't produce

class SupplyChain:
    def __init__(self):
        self.nodes = []
        self.edges = []

    def add_node(self, node):
        self.nodes.append(node)

    def add_edge(self, source, target, unit_price, initial_quantity, min_cost, max_cost):
        edge = Edge(unit_price, min_cost, max_cost)
        edge.initialize(initial_quantity)
        self.edges.append(edge)
        source.add_outgoing_edge(edge, target)
        target.add_incoming_edge(edge, source)

    def update(self):
        for node in self.nodes:
            node.update()

# %% [markdown]
# ## Mock Supply Chain

# %%
def create_supply_chain():
    supply_chain = SupplyChain()

    # Create leaf nodes with random cost types
    leaf1 = LeafNode(200, "raw_material_1", [(0, 10), (5, 15), (10, 20)], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    leaf2 = LeafNode(250, "raw_material_2", [(0, 15), (5, 20), (10, 25)], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    leaf3 = LeafNode(220, "raw_material_3", [(0, 12), (5, 18), (10, 22)], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(leaf1)
    supply_chain.add_node(leaf2)
    supply_chain.add_node(leaf3)

    # Create intermediate nodes with random cost types
    intermediate_a1 = CombinerNode(300, "intermediate_a1", [0.8, 1.0], [1, 1.2], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    intermediate_a2 = CombinerNode(280, "intermediate_a2", [0.9, 1.1], [1.1, 1.3], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(intermediate_a1)
    supply_chain.add_node(intermediate_a2)

    intermediate_b1 = CombinerNode(300, "intermediate_b1", [0.8, 1.0], [1, 1.2], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    intermediate_b2 = CombinerNode(280, "intermediate_b2", [0.9, 1.1], [1.1, 1.3], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(intermediate_b1)
    supply_chain.add_node(intermediate_b2)

    # Create final combiner node with random cost type
    final_combiner = CombinerNode(350, "final_product", [0.7, 0.8, 0.9], [1, 1.1, 1.2], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(final_combiner)

    # Create sink node with random cost type
    sink = SinkNode(consumption_rate=250, cost_type=random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(sink)

    # Add edges with cost ranges
    supply_chain.add_edge(leaf1, intermediate_a1, 10, 30, 5, 15)
    supply_chain.add_edge(leaf2, intermediate_a1, 15, 35, 8, 20)
    supply_chain.add_edge(leaf2, intermediate_a2, 12, 30, 6, 18)
    supply_chain.add_edge(leaf3, intermediate_a2, 14, 32, 7, 19)
    supply_chain.add_edge(intermediate_a1, intermediate_b1, 20, 40, 10, 25)
    supply_chain.add_edge(intermediate_a2, intermediate_b1, 22, 42, 11, 27)
    supply_chain.add_edge(intermediate_b1, final_combiner, 20, 40, 10, 25)
    supply_chain.add_edge(intermediate_b2, final_combiner, 22, 42, 11, 27)
    supply_chain.add_edge(leaf3, final_combiner, 18, 35, 9, 23)
    supply_chain.add_edge(final_combiner, sink, 25, 50, 13, 30)

    return supply_chain

# %%
# Simulation
time = 0
supply_chain = create_supply_chain()

for _ in range(200):  # Simulate for 200 time steps
    supply_chain.update()
    time += 1

    # Print current state
    print(f"Time: {time}")
    for node in supply_chain.nodes:
        print(f"Node ({node.node_class}): Inventory = {node.inventory}, Last Production = {node.last_production}, Cost Type = {node.cost_type}")
        for edge, target_node in node.outgoing_edges:
            print(f"  Edge to {target_node.node_class}: Quantity = {edge.quantity}, Cost = {edge.current_cost:.2f}")
    print("---")
# Out:
# Time: 1
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 30, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 35, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 30, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 32, Cost = 7.38
#   Edge to final_product: Quantity = 35, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 95, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 137, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 42, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 120, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 40, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 42, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 140, Cost Type = fixed
#   Edge to sink: Quantity = 50, Cost = 21.50
# Node (sink): Inventory = 0, Last Production = 50, Cost Type = fixed
# ---
# Time: 2
# Node (raw_material_1): Inventory = 0, Last Production = 11, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 10, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 16, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 8, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 6, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 13, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 160, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 199, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 202, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 141, Cost Type = fixed
#   Edge to sink: Quantity = 257, Cost = 21.50
# Node (sink): Inventory = 7, Last Production = 250, Cost Type = fixed
# ---
# Time: 3
# Node (raw_material_1): Inventory = 0, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 11, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 17, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 9, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 7, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 14, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.49
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 22, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 80, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 42, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 107, Last Production = 250, Cost Type = fixed
# ---
# Time: 4
# Node (raw_material_1): Inventory = 0, Last Production = 13, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 12, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 18, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 7, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.49
#   Edge to final_product: Quantity = 8, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 25, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 42, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 95, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 144, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 207, Last Production = 250, Cost Type = fixed
# ---
# Time: 5
# Node (raw_material_1): Inventory = 0, Last Production = 14, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 13, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 19, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 8, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 16, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 7, Cost = 7.55
#   Edge to final_product: Quantity = 8, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 26, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 47, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 22, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 99, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 168, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 129, Cost Type = fixed
#   Edge to sink: Quantity = 265, Cost = 21.50
# Node (sink): Inventory = 222, Last Production = 250, Cost Type = fixed
# ---
# Time: 6
# Node (raw_material_1): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 14, Cost = 5.05
# Node (raw_material_2): Inventory = 1, Last Production = 20, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 11, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 8, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 7, Cost = 7.60
#   Edge to final_product: Quantity = 9, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 28, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 49, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 22, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 37, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 115, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 177, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 137, Cost Type = fixed
#   Edge to sink: Quantity = 306, Cost = 21.50
# Node (sink): Inventory = 278, Last Production = 250, Cost Type = fixed
# ---
# Time: 7
# Node (raw_material_1): Inventory = 0, Last Production = 16, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 14, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 21, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 11, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 9, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 8, Cost = 7.60
#   Edge to final_product: Quantity = 10, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 28, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 53, Cost = 10.00
# Node (intermediate_a2): Inventory = 1, Last Production = 26, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 37, Cost = 11.06
# Node (intermediate_b1): Inventory = 0, Last Production = 118, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 201, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 138, Cost Type = fixed
#   Edge to sink: Quantity = 324, Cost = 21.50
# Node (sink): Inventory = 352, Last Production = 250, Cost Type = fixed
# ---
# Time: 8
# Node (raw_material_1): Inventory = 0, Last Production = 17, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 17, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 22, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 12, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 9, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 19, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 8, Cost = 7.65
#   Edge to final_product: Quantity = 10, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 33, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 53, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 26, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 42, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 131, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 208, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 131, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 452, Last Production = 250, Cost Type = fixed
# ---
# Time: 9
# Node (raw_material_1): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 17, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 23, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 12, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 10, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 20, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 8, Cost = 7.65
#   Edge to final_product: Quantity = 11, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 33, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 62, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 27, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 44, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 143, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 226, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 552, Last Production = 250, Cost Type = fixed
# ---
# Time: 10
# Node (raw_material_1): Inventory = 0, Last Production = 19, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 18, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 24, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 13, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 10, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 21, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 9, Cost = 7.71
#   Edge to final_product: Quantity = 11, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 36, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 62, Cost = 10.00
# Node (intermediate_a2): Inventory = 1, Last Production = 30, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 45, Cost = 11.06
# Node (intermediate_b1): Inventory = 0, Last Production = 145, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 249, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 89, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 652, Last Production = 250, Cost Type = fixed
# ---
# Time: 11
# Node (raw_material_1): Inventory = 0, Last Production = 20, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 19, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 25, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 13, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 11, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 22, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 9, Cost = 7.71
#   Edge to final_product: Quantity = 12, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 36, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 67, Cost = 10.00
# Node (intermediate_a2): Inventory = 1, Last Production = 31, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 48, Cost = 11.06
# Node (intermediate_b1): Inventory = 0, Last Production = 157, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 252, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 85, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 752, Last Production = 250, Cost Type = fixed
# ---
# Time: 12
# Node (raw_material_1): Inventory = 0, Last Production = 21, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 20, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 26, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 14, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 11, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 22, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 10, Cost = 7.76
#   Edge to final_product: Quantity = 12, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 39, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 68, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 34, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 51, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 166, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 272, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 65, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 852, Last Production = 250, Cost Type = fixed
# ---
# Time: 13
# Node (raw_material_1): Inventory = 0, Last Production = 22, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 21, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 27, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 14, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 12, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 23, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 9, Cost = 7.76
#   Edge to final_product: Quantity = 13, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 40, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 73, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 32, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 56, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 171, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 285, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 51, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 952, Last Production = 250, Cost Type = fixed
# ---
# Time: 14
# Node (raw_material_1): Inventory = 0, Last Production = 23, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 22, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 28, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 15, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 12, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 24, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 10, Cost = 7.82
#   Edge to final_product: Quantity = 13, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 43, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 75, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 35, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 53, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 172, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 36, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1052, Last Production = 250, Cost Type = fixed
# ---
# Time: 15
# Node (raw_material_1): Inventory = 0, Last Production = 24, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 23, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 29, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 15, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 13, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 25, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 10, Cost = 7.82
#   Edge to final_product: Quantity = 14, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 44, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 80, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 37, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 57, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 163, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 35, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1152, Last Production = 250, Cost Type = fixed
# ---
# Time: 16
# Node (raw_material_1): Inventory = 0, Last Production = 25, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 24, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 30, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 16, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 13, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 26, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 11, Cost = 7.87
#   Edge to final_product: Quantity = 14, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 47, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 82, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 39, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 60, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 158, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 35, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1252, Last Production = 250, Cost Type = fixed
# ---
# Time: 17
# Node (raw_material_1): Inventory = 0, Last Production = 26, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 25, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 31, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 16, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 14, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 26, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 11, Cost = 7.87
#   Edge to final_product: Quantity = 15, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 47, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 87, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 41, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 63, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 150, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 34, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1352, Last Production = 250, Cost Type = fixed
# ---
# Time: 18
# Node (raw_material_1): Inventory = 0, Last Production = 27, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 26, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 32, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 17, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 14, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 27, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 11, Cost = 7.93
#   Edge to final_product: Quantity = 15, Cost = 9.06
# Node (intermediate_a1): Inventory = 1, Last Production = 50, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 88, Cost = 10.05
# Node (intermediate_a2): Inventory = 0, Last Production = 41, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 66, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 146, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 34, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1452, Last Production = 250, Cost Type = fixed
# ---
# Time: 19
# Node (raw_material_1): Inventory = 0, Last Production = 28, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 27, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 33, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 17, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 15, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 28, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 11, Cost = 7.93
#   Edge to final_product: Quantity = 16, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 51, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 92, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 42, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 66, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 142, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 33, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1552, Last Production = 250, Cost Type = fixed
# ---
# Time: 20
# Node (raw_material_1): Inventory = 0, Last Production = 29, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 28, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 34, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 18, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 15, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 29, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 12, Cost = 7.98
#   Edge to final_product: Quantity = 16, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 54, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 96, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 45, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 68, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 136, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 33, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1652, Last Production = 250, Cost Type = fixed
# ---
# Time: 21
# Node (raw_material_1): Inventory = 0, Last Production = 30, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 29, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 35, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 18, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 16, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 30, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 12, Cost = 7.98
#   Edge to final_product: Quantity = 17, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 55, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 100, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 46, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 72, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 128, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 32, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1752, Last Production = 250, Cost Type = fixed
# ---
# Time: 22
# Node (raw_material_1): Inventory = 1, Last Production = 31, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 30, Cost = 5.05
# Node (raw_material_2): Inventory = 1, Last Production = 36, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 19, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 16, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 30, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 13, Cost = 8.04
#   Edge to final_product: Quantity = 17, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 58, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 102, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 49, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 74, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 124, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 32, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1852, Last Production = 250, Cost Type = fixed
# ---
# Time: 23
# Node (raw_material_1): Inventory = 0, Last Production = 32, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 30, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 37, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 19, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 17, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 31, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 12, Cost = 8.04
#   Edge to final_product: Quantity = 18, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 58, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 107, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 48, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 78, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 115, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 31, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 1952, Last Production = 250, Cost Type = fixed
# ---
# Time: 24
# Node (raw_material_1): Inventory = 0, Last Production = 33, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 33, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 38, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 20, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 17, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 32, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 13, Cost = 8.09
#   Edge to final_product: Quantity = 18, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 62, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 107, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 51, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 77, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 116, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 31, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2052, Last Production = 250, Cost Type = fixed
# ---
# Time: 25
# Node (raw_material_1): Inventory = 0, Last Production = 34, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 33, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 39, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 20, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 18, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 33, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 13, Cost = 8.09
#   Edge to final_product: Quantity = 19, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 62, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 115, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 52, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 81, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 104, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 30, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2152, Last Production = 250, Cost Type = fixed
# ---
# Time: 26
# Node (raw_material_1): Inventory = 0, Last Production = 35, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 34, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 40, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 21, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 18, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 34, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 14, Cost = 8.15
#   Edge to final_product: Quantity = 19, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 65, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 115, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 55, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 83, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 102, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 30, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2252, Last Production = 250, Cost Type = fixed
# ---
# Time: 27
# Node (raw_material_1): Inventory = 0, Last Production = 36, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 35, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 41, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 21, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 19, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 34, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 14, Cost = 8.15
#   Edge to final_product: Quantity = 20, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 66, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 120, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 56, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 87, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 93, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 29, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2352, Last Production = 250, Cost Type = fixed
# ---
# Time: 28
# Node (raw_material_1): Inventory = 0, Last Production = 37, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 36, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 42, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 22, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 19, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 35, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 14, Cost = 8.20
#   Edge to final_product: Quantity = 20, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 69, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 122, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 56, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 89, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 89, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 29, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2452, Last Production = 250, Cost Type = fixed
# ---
# Time: 29
# Node (raw_material_1): Inventory = 0, Last Production = 38, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 37, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 43, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 22, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 20, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 36, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 14, Cost = 8.20
#   Edge to final_product: Quantity = 21, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 70, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 127, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 58, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 89, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 84, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 28, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2552, Last Production = 250, Cost Type = fixed
# ---
# Time: 30
# Node (raw_material_1): Inventory = 1, Last Production = 39, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 38, Cost = 5.05
# Node (raw_material_2): Inventory = 1, Last Production = 44, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 23, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 20, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 37, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 15, Cost = 8.25
#   Edge to final_product: Quantity = 21, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 73, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 129, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 61, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 92, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 79, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 28, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2652, Last Production = 250, Cost Type = fixed
# ---
# Time: 31
# Node (raw_material_1): Inventory = 0, Last Production = 40, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 38, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 45, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 23, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 21, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 38, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 15, Cost = 8.25
#   Edge to final_product: Quantity = 22, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 73, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 134, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 62, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 96, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 70, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 27, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2752, Last Production = 250, Cost Type = fixed
# ---
# Time: 32
# Node (raw_material_1): Inventory = 0, Last Production = 41, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 41, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 46, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 24, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 21, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 38, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 16, Cost = 8.31
#   Edge to final_product: Quantity = 22, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 78, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 134, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 66, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 98, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 68, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 27, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2852, Last Production = 250, Cost Type = fixed
# ---
# Time: 33
# Node (raw_material_1): Inventory = 0, Last Production = 42, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 41, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 47, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 24, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 22, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 39, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 15, Cost = 8.31
#   Edge to final_product: Quantity = 23, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 78, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 143, Cost = 10.00
# Node (intermediate_a2): Inventory = 1, Last Production = 64, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 103, Cost = 11.06
# Node (intermediate_b1): Inventory = 0, Last Production = 54, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 26, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 2952, Last Production = 250, Cost Type = fixed
# ---
# Time: 34
# Node (raw_material_1): Inventory = 0, Last Production = 43, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 42, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 48, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 25, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 22, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 40, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 16, Cost = 8.36
#   Edge to final_product: Quantity = 23, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 81, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 143, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 67, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 100, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 57, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 26, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 3052, Last Production = 250, Cost Type = fixed
# ---
# Time: 35
# Node (raw_material_1): Inventory = 0, Last Production = 44, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 43, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 49, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 25, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 23, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 41, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 16, Cost = 8.36
#   Edge to final_product: Quantity = 24, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 81, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 148, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 68, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 106, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 46, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 25, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 3152, Last Production = 250, Cost Type = fixed
# ---
# Time: 36
# Node (raw_material_1): Inventory = 0, Last Production = 45, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 44, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 50, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 26, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 23, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 42, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 17, Cost = 8.42
#   Edge to final_product: Quantity = 24, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 85, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 149, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 72, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 107, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 44, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 25, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 3252, Last Production = 250, Cost Type = fixed
# ---
# Time: 37
# Node (raw_material_1): Inventory = 0, Last Production = 46, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 45, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 51, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 26, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 24, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 42, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 17, Cost = 8.42
#   Edge to final_product: Quantity = 25, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 85, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 155, Cost = 10.00
# Node (intermediate_a2): Inventory = 1, Last Production = 73, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 112, Cost = 11.06
# Node (intermediate_b1): Inventory = 0, Last Production = 33, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 24, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 3352, Last Production = 250, Cost Type = fixed
# ---
# Time: 38
# ...
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 18452, Last Production = 250, Cost Type = fixed
# ---
# Time: 189
# Node (raw_material_1): Inventory = 1, Last Production = 198, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 197, Cost = 5.05
# Node (raw_material_2): Inventory = 1, Last Production = 203, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 102, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 100, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 164, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 62, Cost = 12.56
#   Edge to final_product: Quantity = 101, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 1, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 118, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 18552, Last Production = 250, Cost Type = fixed
# ---
# Time: 190
# Node (raw_material_1): Inventory = 0, Last Production = 199, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 197, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 204, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 103, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 100, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 165, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 63, Cost = 12.62
#   Edge to final_product: Quantity = 101, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 117, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 18652, Last Production = 250, Cost Type = fixed
# ---
# Time: 191
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 205, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 103, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 101, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 166, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 63, Cost = 12.62
#   Edge to final_product: Quantity = 102, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 116, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 18752, Last Production = 250, Cost Type = fixed
# ---
# Time: 192
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 206, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 104, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 101, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 166, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 64, Cost = 12.67
#   Edge to final_product: Quantity = 102, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 115, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 18852, Last Production = 250, Cost Type = fixed
# ---
# Time: 193
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 207, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 104, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 102, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 167, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 63, Cost = 12.67
#   Edge to final_product: Quantity = 103, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 115, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 18952, Last Production = 250, Cost Type = fixed
# ---
# Time: 194
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 208, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 105, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 102, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 168, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 64, Cost = 12.73
#   Edge to final_product: Quantity = 103, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 114, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 19052, Last Production = 250, Cost Type = fixed
# ---
# Time: 195
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 209, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 105, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 103, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 169, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 64, Cost = 12.73
#   Edge to final_product: Quantity = 104, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 113, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 19152, Last Production = 250, Cost Type = fixed
# ---
# Time: 196
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 210, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 106, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 103, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 170, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 65, Cost = 12.78
#   Edge to final_product: Quantity = 104, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 112, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 19252, Last Production = 250, Cost Type = fixed
# ---
# Time: 197
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 211, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 106, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 104, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 170, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 65, Cost = 12.78
#   Edge to final_product: Quantity = 105, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 111, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 19352, Last Production = 250, Cost Type = fixed
# ---
# Time: 198
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 212, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 107, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 104, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 171, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 65, Cost = 12.84
#   Edge to final_product: Quantity = 105, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 111, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 19452, Last Production = 250, Cost Type = fixed
# ---
# Time: 199
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 213, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 107, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 105, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 172, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 65, Cost = 12.84
#   Edge to final_product: Quantity = 106, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 110, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 19552, Last Production = 250, Cost Type = fixed
# ---
# Time: 200
# Node (raw_material_1): Inventory = 0, Last Production = 200, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 200, Cost = 5.00
# Node (raw_material_2): Inventory = 1, Last Production = 214, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 108, Cost = 14.00
#   Edge to intermediate_a2: Quantity = 105, Cost = 12.00
# Node (raw_material_3): Inventory = 1, Last Production = 173, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 66, Cost = 12.89
#   Edge to final_product: Quantity = 106, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 0, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 300, Cost = 10.00
# Node (intermediate_a2): Inventory = 0, Last Production = 109, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 280, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 0, Cost Type = fixed
#   Edge to sink: Quantity = 350, Cost = 21.50
# Node (sink): Inventory = 19652, Last Production = 250, Cost Type = fixed
# ---

# %% [markdown]
# ## Recording of the simulation

# %%
import pandas as pd
import uuid

def simulate_and_collect_data(supply_chain, n_cycles):
    # Initialize DataFrames
    metadata = []
    node_data = []
    edge_data = []
    
    node_id = 0

    # Create metadata and assign unique IDs
    for node in supply_chain.nodes:
        metadata.append({
            'node_id': f"node_{node_id}",
            'node_class': node.node_class,
            'max_inventory': node.max_inventory,
            'cost_type': node.cost_type
        })
        node.id = node_id  # Assign ID to node object for reference
        node_id += 1

    edge_id = 0
    # Create edge metadata
    for edge in supply_chain.edges:
        source_node = None
        target_node = None
        
        for node in supply_chain.nodes:
            if edge in [e for e, _ in node.outgoing_edges]:
                source_node = node
            if edge in [e for e, _ in node.incoming_edges]:
                target_node = node
            if source_node and target_node:
                break
        
        if not source_node or not target_node:
            print(f"Warning: Edge {edge_id} is not properly connected.")
            print(f"Source node: {source_node.node_class if source_node else 'None'}")
            print(f"Target node: {target_node.node_class if target_node else 'None'}")
            continue
        
        metadata.append({
            'edge_id': f"edge_{edge_id}",
            'source_node_id': source_node.id,
            'target_node_id': target_node.id,
            'unit_price': edge.unit_price,
            'min_cost': edge.min_cost,
            'max_cost': edge.max_cost
        })
        edge.id = edge_id  # Assign ID to edge object for reference
        edge_id += 1

    # Simulate for n cycles
    for cycle in range(n_cycles):
        supply_chain.update()

        # Collect node data
        for node in supply_chain.nodes:
            node_data.append({
                'cycle': cycle,
                'node_id': f"node_{node.id}",
                'inventory': node.inventory,
                'last_production': node.last_production
            })

        # Collect edge data
        for edge in supply_chain.edges:
            if hasattr(edge, 'id'):  # Only collect data for edges that were properly connected
                edge_data.append({
                    'cycle': cycle,
                    'edge_id': f"edge_{edge.id}",
                    'quantity': edge.quantity,
                    'current_cost': edge.current_cost
                })

    # Create DataFrames
    metadata_df = pd.DataFrame(metadata)
    node_data_df = pd.DataFrame(node_data)
    edge_data_df = pd.DataFrame(edge_data)

    return metadata_df, node_data_df, edge_data_df

# %%
supply_chain = create_supply_chain()
metadata_df, node_data_df, edge_data_df = simulate_and_collect_data(supply_chain, n_cycles=200)

# %%
metadata_df
# Out:
#    node_id       node_class  max_inventory         cost_type edge_id  \
# 0   node_0   raw_material_1          200.0  negative_dynamic     NaN
# 1   node_1   raw_material_2          250.0  negative_dynamic     NaN
# 2   node_2   raw_material_3          220.0             fixed     NaN
# 3   node_3  intermediate_a1          300.0  negative_dynamic     NaN
# 4   node_4  intermediate_a2          280.0  negative_dynamic     NaN
# 5   node_5  intermediate_b1          300.0             fixed     NaN
# 6   node_6  intermediate_b2          280.0             fixed     NaN
# 7   node_7    final_product          350.0  negative_dynamic     NaN
# 8   node_8             sink            inf             fixed     NaN
# 9      NaN              NaN            NaN               NaN  edge_0
# 10     NaN              NaN            NaN               NaN  edge_1
# 11     NaN              NaN            NaN               NaN  edge_2
# 12     NaN              NaN            NaN               NaN  edge_3
# 13     NaN              NaN            NaN               NaN  edge_4
# 14     NaN              NaN            NaN               NaN  edge_5
# 15     NaN              NaN            NaN               NaN  edge_6
# 16     NaN              NaN            NaN               NaN  edge_7
# 17     NaN              NaN            NaN               NaN  edge_8
# 18     NaN              NaN            NaN               NaN  edge_9
#
#     source_node_id  target_node_id  unit_price  min_cost  max_cost
# 0              NaN             NaN         NaN       NaN       NaN
# 1              NaN             NaN         NaN       NaN       NaN
# 2              NaN             NaN         NaN       NaN       NaN
# 3              NaN             NaN         NaN       NaN       NaN
# 4              NaN             NaN         NaN       NaN       NaN
# 5              NaN             NaN         NaN       NaN       NaN
# 6              NaN             NaN         NaN       NaN       NaN
# 7              NaN             NaN         NaN       NaN       NaN
# 8              NaN             NaN         NaN       NaN       NaN
# 9              0.0             3.0        10.0       5.0      15.0
# 10             1.0             3.0        15.0       8.0      20.0
# 11             1.0             4.0        12.0       6.0      18.0
# 12             2.0             4.0        14.0       7.0      19.0
# 13             3.0             5.0        20.0      10.0      25.0
# 14             4.0             5.0        22.0      11.0      27.0
# 15             5.0             7.0        20.0      10.0      25.0
# 16             6.0             7.0        22.0      11.0      27.0
# 17             2.0             7.0        18.0       9.0      23.0
# 18             7.0             8.0        25.0      13.0      30.0

# %%
node_data_df
# Out:
#       cycle node_id  inventory  last_production
# 0         0  node_0          0              200
# 1         0  node_1          1              215
# 2         0  node_2          1              174
# 3         0  node_3          0               95
# 4         0  node_4          0              137
# ...     ...     ...        ...              ...
# 1795    199  node_4          0               98
# 1796    199  node_5          0                0
# 1797    199  node_6          0                1
# 1798    199  node_7          0                0
# 1799    199  node_8      19807              250
#
# [1800 rows x 4 columns]

# %%
edge_data_df
# Out:
#       cycle edge_id  quantity  current_cost
# 0         0  edge_0        30        15.000
# 1         0  edge_1        35        15.200
# 2         0  edge_2        30        17.952
# 3         0  edge_3        32        13.000
# 4         0  edge_4        40        25.000
# ...     ...     ...       ...           ...
# 1995    199  edge_5       280        27.000
# 1996    199  edge_6       300        17.500
# 1997    199  edge_7         1        19.000
# 1998    199  edge_8        91        16.000
# 1999    199  edge_9       350        30.000
#
# [2000 rows x 4 columns]

# %% [markdown]
# ## Conversion between JSON and DataFrames

# %%
import pandas as pd
import json
from typing import Dict, List

def dataframes_to_json(metadata: pd.DataFrame, node: pd.DataFrame, edge: pd.DataFrame) -> str:
    bom = {
        "metadata": metadata.to_dict(orient='records'),
        "nodes": {},
        "edges": {}
    }

    # Process node data
    for _, row in node.iterrows():
        node_id = row['node_id']
        cycle = row['cycle']
        if node_id not in bom["nodes"]:
            bom["nodes"][node_id] = {}
        bom["nodes"][node_id][cycle] = row.to_dict()

    # Process edge data
    for _, row in edge.iterrows():
        edge_id = row['edge_id']
        cycle = row['cycle']
        if edge_id not in bom["edges"]:
            bom["edges"][edge_id] = {}
        bom["edges"][edge_id][cycle] = row.to_dict()

    return json.dumps(bom, indent=2)

def json_to_dataframes(json_data: str) -> Dict[str, pd.DataFrame]:
    bom = json.loads(json_data)

    # Create empty lists to store the data
    node_data = []
    edge_data = []

    # Process nodes
    for node_id, cycles in bom["nodes"].items():
        for cycle, node_info in cycles.items():
            node_data.append(node_info)

    # Process edges
    for edge_id, cycles in bom["edges"].items():
        for cycle, edge_info in cycles.items():
            edge_data.append(edge_info)

    # Create DataFrames
    metadata_df = pd.DataFrame(bom["metadata"])
    node_df = pd.DataFrame(node_data)
    edge_df = pd.DataFrame(edge_data)

    return {
        "metadata": metadata_df,
        "node": node_df,
        "edge": edge_df
    }

# %%
# Convert dataframes to JSON
json_string = dataframes_to_json(metadata_df, node_data_df, edge_data_df)

# %%
json_data = json.loads(json_string)
json_data
# Out:
# {'metadata': [{'node_id': 'node_0',
#    'node_class': 'raw_material_1',
#    'max_inventory': 200.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_1',
#    'node_class': 'raw_material_2',
#    'max_inventory': 250.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_2',
#    'node_class': 'raw_material_3',
#    'max_inventory': 220.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_3',
#    'node_class': 'intermediate_a1',
#    'max_inventory': 300.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_4',
#    'node_class': 'intermediate_a2',
#    'max_inventory': 280.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_5',
#    'node_class': 'intermediate_b1',
#    'max_inventory': 300.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_6',
#    'node_class': 'intermediate_b2',
#    'max_inventory': 280.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_7',
#    'node_class': 'final_product',
#    'max_inventory': 350.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_8',
#    'node_class': 'sink',
#    'max_inventory': inf,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_0',
#    'source_node_id': 0.0,
#    'target_node_id': 3.0,
#    'unit_price': 10.0,
#    'min_cost': 5.0,
#    'max_cost': 15.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_1',
#    'source_node_id': 1.0,
#    'target_node_id': 3.0,
#    'unit_price': 15.0,
#    'min_cost': 8.0,
#    'max_cost': 20.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_2',
#    'source_node_id': 1.0,
#    'target_node_id': 4.0,
#    'unit_price': 12.0,
#    'min_cost': 6.0,
#    'max_cost': 18.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_3',
#    'source_node_id': 2.0,
#    'target_node_id': 4.0,
#    'unit_price': 14.0,
#    'min_cost': 7.0,
#    'max_cost': 19.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_4',
#    'source_node_id': 3.0,
#    'target_node_id': 5.0,
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_5',
#    'source_node_id': 4.0,
#    'target_node_id': 5.0,
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_6',
#    'source_node_id': 5.0,
#    'target_node_id': 7.0,
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_7',
#    'source_node_id': 6.0,
#    'target_node_id': 7.0,
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_8',
#    'source_node_id': 2.0,
#    'target_node_id': 7.0,
#    'unit_price': 18.0,
#    'min_cost': 9.0,
#    'max_cost': 23.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_9',
#    'source_node_id': 7.0,
#    'target_node_id': 8.0,
#    'unit_price': 25.0,
#    'min_cost': 13.0,
#    'max_cost': 30.0}],
#  'nodes': {'node_0': {'0': {'cycle': 0,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '1': {'cycle': 1,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '2': {'cycle': 2,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '3': {'cycle': 3,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '4': {'cycle': 4,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '5': {'cycle': 5,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '6': {'cycle': 6,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '7': {'cycle': 7,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '8': {'cycle': 8,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '9': {'cycle': 9,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '10': {'cycle': 10,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '11': {'cycle': 11,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '12': {'cycle': 12,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '13': {'cycle': 13,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '14': {'cycle': 14,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '15': {'cycle': 15,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '16': {'cycle': 16,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '17': {'cycle': 17,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '18': {'cycle': 18,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '19': {'cycle': 19,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '20': {'cycle': 20,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '21': {'cycle': 21,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '22': {'cycle': 22,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '23': {'cycle': 23,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '24': {'cycle': 24,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '25': {'cycle': 25,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '26': {'cycle': 26,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '27': {'cycle': 27,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '28': {'cycle': 28,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '29': {'cycle': 29,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '30': {'cycle': 30,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '31': {'cycle': 31,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '32': {'cycle': 32,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '33': {'cycle': 33,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '34': {'cycle': 34,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '35': {'cycle': 35,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '36': {'cycle': 36,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '37': {'cycle': 37,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '38': {'cycle': 38,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '39': {'cycle': 39,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '40': {'cycle': 40,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '41': {'cycle': 41,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '42': {'cycle': 42,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '43': {'cycle': 43,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '44': {'cycle': 44,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '45': {'cycle': 45,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '46': {'cycle': 46,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    

#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '105': {'cycle': 105,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '106': {'cycle': 106,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '107': {'cycle': 107,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '108': {'cycle': 108,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '109': {'cycle': 109,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '110': {'cycle': 110,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '111': {'cycle': 111,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '112': {'cycle': 112,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '113': {'cycle': 113,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '114': {'cycle': 114,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '115': {'cycle': 115,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '116': {'cycle': 116,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '117': {'cycle': 117,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '118': {'cycle': 118,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '119': {'cycle': 119,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '120': {'cycle': 120,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '121': {'cycle': 121,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '122': {'cycle': 122,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '123': {'cycle': 123,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '124': {'cycle': 124,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '125': {'cycle': 125,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '126': {'cycle': 126,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '127': {'cycle': 127,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '128': {'cycle': 128,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '129': {'cycle': 129,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '130': {'cycle': 130,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '131': {'cycle': 131,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '132': {'cycle': 132,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '133': {'cycle': 133,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '134': {'cycle': 134,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '135': {'cycle': 135,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '136': {'cycle': 136,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '137': {'cycle': 137,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '138': {'cycle': 138,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '139': {'cycle': 139,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '140': {'cycle': 140,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '141': {'cycle': 141,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '142': {'cycle': 142,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '143': {'cycle': 143,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '144': {'cycle': 144,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '145': {'cycle': 145,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '146': {'cycle': 146,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '147': {'cycle': 147,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '148': {'cycle': 148,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '149': {'cycle': 149,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '150': {'cycle': 150,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '151': {'cycle': 151,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '152': {'cycle': 152,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '153': {'cycle': 153,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '154': {'cycle': 154,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '155': {'cycle': 155,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '156': {'cycle': 156,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '157': {'cycle': 157,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '158': {'cycle': 158,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '159': {'cycle': 159,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '160': {'cycle': 160,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '161': {'cycle': 161,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '162': {'cycle': 162,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '163': {'cycle': 163,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '164': {'cycle': 164,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '165': {'cycle': 165,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '166': {'cycle': 166,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '167': {'cycle': 167,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '168': {'cycle': 168,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '169': {'cycle': 169,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '170': {'cycle': 170,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '171': {'cycle': 171,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '172': {'cycle': 172,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '173': {'cycle': 173,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '174': {'cycle': 174,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '175': {'cycle': 175,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '176': {'cycle': 176,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '177': {'cycle': 177,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '178': {'cycle': 178,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '179': {'cycle': 179,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '180': {'cycle': 180,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '181': {'cycle': 181,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '182': {'cycle': 182,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '183': {'cycle': 183,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '184': {'cycle': 184,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '185': {'cycle': 185,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '186': {'cycle': 186,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '187': {'cycle': 187,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '188': {'cycle': 188,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '189': {'cycle': 189,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '190': {'cycle': 190,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '191': {'cycle': 191,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '192': {'cycle': 192,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '193': {'cycle': 193,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '194': {'cycle': 194,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '195': {'cycle': 195,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '196': {'cycle': 196,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '197': {'cycle': 197,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '198': {'cycle': 198,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0},
#    '199': {'cycle': 199,
#     'edge_id': 'edge_9',
#     'quantity': 350,
#     'current_cost': 30.0}}}}

# %%
if SAVE_RECORDS:
    import json
    with open('../data/json/true.json', 'w') as f:
        json.dump(json_data, f, ensure_ascii=False)

# %%
# Convert JSON back to dataframes
reconstructed_dfs = json_to_dataframes(json_string)

# Access the reconstructed dataframes
reconstructed_metadata = reconstructed_dfs['metadata']
reconstructed_node = reconstructed_dfs['node']
reconstructed_edge = reconstructed_dfs['edge']

# %%
if SAVE_RECORDS:
    reconstructed_metadata.to_csv('../data/csv/metadata.csv', index=False)
    reconstructed_node.to_csv('../data/csv/node.csv', index=False)
    reconstructed_edge.to_csv('../data/csv/edge.csv', index=False)

# %%
reconstructed_metadata
# Out:
#    node_id       node_class  max_inventory         cost_type edge_id  \
# 0   node_0   raw_material_1          200.0  negative_dynamic     NaN
# 1   node_1   raw_material_2          250.0  negative_dynamic     NaN
# 2   node_2   raw_material_3          220.0             fixed     NaN
# 3   node_3  intermediate_a1          300.0  negative_dynamic     NaN
# 4   node_4  intermediate_a2          280.0  negative_dynamic     NaN
# 5   node_5  intermediate_b1          300.0             fixed     NaN
# 6   node_6  intermediate_b2          280.0             fixed     NaN
# 7   node_7    final_product          350.0  negative_dynamic     NaN
# 8   node_8             sink            inf             fixed     NaN
# 9      NaN              NaN            NaN               NaN  edge_0
# 10     NaN              NaN            NaN               NaN  edge_1
# 11     NaN              NaN            NaN               NaN  edge_2
# 12     NaN              NaN            NaN               NaN  edge_3
# 13     NaN              NaN            NaN               NaN  edge_4
# 14     NaN              NaN            NaN               NaN  edge_5
# 15     NaN              NaN            NaN               NaN  edge_6
# 16     NaN              NaN            NaN               NaN  edge_7
# 17     NaN              NaN            NaN               NaN  edge_8
# 18     NaN              NaN            NaN               NaN  edge_9
#
#     source_node_id  target_node_id  unit_price  min_cost  max_cost
# 0              NaN             NaN         NaN       NaN       NaN
# 1              NaN             NaN         NaN       NaN       NaN
# 2              NaN             NaN         NaN       NaN       NaN
# 3              NaN             NaN         NaN       NaN       NaN
# 4              NaN             NaN         NaN       NaN       NaN
# 5              NaN             NaN         NaN       NaN       NaN
# 6              NaN             NaN         NaN       NaN       NaN
# 7              NaN             NaN         NaN       NaN       NaN
# 8              NaN             NaN         NaN       NaN       NaN
# 9              0.0             3.0        10.0       5.0      15.0
# 10             1.0             3.0        15.0       8.0      20.0
# 11             1.0             4.0        12.0       6.0      18.0
# 12             2.0             4.0        14.0       7.0      19.0
# 13             3.0             5.0        20.0      10.0      25.0
# 14             4.0             5.0        22.0      11.0      27.0
# 15             5.0             7.0        20.0      10.0      25.0
# 16             6.0             7.0        22.0      11.0      27.0
# 17             2.0             7.0        18.0       9.0      23.0
# 18             7.0             8.0        25.0      13.0      30.0

# %%
reconstructed_node
# Out:
#       cycle node_id  inventory  last_production
# 0         0  node_0          0              200
# 1         1  node_0          0              200
# 2         2  node_0          0              200
# 3         3  node_0          0              200
# 4         4  node_0          0              200
# ...     ...     ...        ...              ...
# 1795    195  node_8      19407              250
# 1796    196  node_8      19507              250
# 1797    197  node_8      19607              250
# 1798    198  node_8      19707              250
# 1799    199  node_8      19807              250
#
# [1800 rows x 4 columns]

# %%
reconstructed_edge
# Out:
#       cycle edge_id  quantity  current_cost
# 0         0  edge_0        30          15.0
# 1         1  edge_0       200          15.0
# 2         2  edge_0       200          15.0
# 3         3  edge_0       200          15.0
# 4         4  edge_0       200          15.0
# ...     ...     ...       ...           ...
# 1995    195  edge_9       350          30.0
# 1996    196  edge_9       350          30.0
# 1997    197  edge_9       350          30.0
# 1998    198  edge_9       350          30.0
# 1999    199  edge_9       350          30.0
#
# [2000 rows x 4 columns]

# %% [markdown]
# ## Aggredation of Cycles and Conversion between JSON and Dataframes

# %%
import pandas as pd
import json
import random
from typing import Dict

def aggregated_dataframes_to_json(metadata: pd.DataFrame, node: pd.DataFrame, edge: pd.DataFrame, max_aggregation_cycles: int = 3) -> str:
    bom = {
        "metadata": metadata.to_dict(orient='records'),
        "nodes": {},
        "edges": {}
    }

    # Initialize variables to track the last cycle
    last_node_cycle = 0
    last_edge_cycle = 0
    
    num_cycles_to_aggregate = random.randint(1, max_aggregation_cycles)

    # Process node data with aggregation
    for _, row in node.iterrows():
        node_id = row['node_id']
        cycle = row['cycle']
        # Check if we can aggregate
        if node_id not in bom["nodes"]:
            bom["nodes"][node_id] = {}
        
        # Aggregate nodes
        for _ in range(num_cycles_to_aggregate):
            last_node_cycle += 1
            # Create a new entry for the aggregated node
            aggregated_node = row.copy()
            aggregated_node['cycle'] = last_node_cycle
            bom["nodes"][node_id][last_node_cycle] = aggregated_node.to_dict()

    # Process edge data with aggregation
    for _, row in edge.iterrows():
        edge_id = row['edge_id']
        cycle = row['cycle']
        # Check if we can aggregate
        if edge_id not in bom["edges"]:
            bom["edges"][edge_id] = {}
        
        # Aggregate edges
        for _ in range(num_cycles_to_aggregate):
            last_edge_cycle += 1
            # Create a new entry for the aggregated edge
            aggregated_edge = row.copy()
            aggregated_edge['cycle'] = last_edge_cycle
            bom["edges"][edge_id][last_edge_cycle] = aggregated_edge.to_dict()

    return json.dumps(bom, indent=2)

# %%
aggregated_json = aggregated_dataframes_to_json(metadata_df, node_data_df, edge_data_df)
aggregated_json_dict = json.loads(aggregated_json)

aggregated_json_dict
# Out:
# {'metadata': [{'node_id': 'node_0',
#    'node_class': 'raw_material_1',
#    'max_inventory': 200.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_1',
#    'node_class': 'raw_material_2',
#    'max_inventory': 250.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_2',
#    'node_class': 'raw_material_3',
#    'max_inventory': 220.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_3',
#    'node_class': 'intermediate_a1',
#    'max_inventory': 300.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_4',
#    'node_class': 'intermediate_a2',
#    'max_inventory': 280.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_5',
#    'node_class': 'intermediate_b1',
#    'max_inventory': 300.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_6',
#    'node_class': 'intermediate_b2',
#    'max_inventory': 280.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_7',
#    'node_class': 'final_product',
#    'max_inventory': 350.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': 'node_8',
#    'node_class': 'sink',
#    'max_inventory': inf,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_0',
#    'source_node_id': 0.0,
#    'target_node_id': 3.0,
#    'unit_price': 10.0,
#    'min_cost': 5.0,
#    'max_cost': 15.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_1',
#    'source_node_id': 1.0,
#    'target_node_id': 3.0,
#    'unit_price': 15.0,
#    'min_cost': 8.0,
#    'max_cost': 20.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_2',
#    'source_node_id': 1.0,
#    'target_node_id': 4.0,
#    'unit_price': 12.0,
#    'min_cost': 6.0,
#    'max_cost': 18.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_3',
#    'source_node_id': 2.0,
#    'target_node_id': 4.0,
#    'unit_price': 14.0,
#    'min_cost': 7.0,
#    'max_cost': 19.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_4',
#    'source_node_id': 3.0,
#    'target_node_id': 5.0,
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_5',
#    'source_node_id': 4.0,
#    'target_node_id': 5.0,
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_6',
#    'source_node_id': 5.0,
#    'target_node_id': 7.0,
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_7',
#    'source_node_id': 6.0,
#    'target_node_id': 7.0,
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_8',
#    'source_node_id': 2.0,
#    'target_node_id': 7.0,
#    'unit_price': 18.0,
#    'min_cost': 9.0,
#    'max_cost': 23.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': 'edge_9',
#    'source_node_id': 7.0,
#    'target_node_id': 8.0,
#    'unit_price': 25.0,
#    'min_cost': 13.0,
#    'max_cost': 30.0}],
#  'nodes': {'node_0': {'1': {'cycle': 1,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '2': {'cycle': 2,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '3': {'cycle': 3,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '28': {'cycle': 28,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '29': {'cycle': 29,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '30': {'cycle': 30,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '55': {'cycle': 55,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '56': {'cycle': 56,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '57': {'cycle': 57,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '82': {'cycle': 82,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '83': {'cycle': 83,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '84': {'cycle': 84,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '109': {'cycle': 109,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '110': {'cycle': 110,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '111': {'cycle': 111,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '136': {'cycle': 136,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '137': {'cycle': 137,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '138': {'cycle': 138,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '163': {'cycle': 163,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '164': {'cycle': 164,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '165': {'cycle': 165,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '190': {'cycle': 190,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '191': {'cycle': 191,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '192': {'cycle': 192,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '217': {'cycle': 217,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '218': {'cycle': 218,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '219': {'cycle': 219,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '244': {'cycle': 244,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '245': {'cycle': 245,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '246': {'cycle': 246,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '271': {'cycle': 271,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '272': {'cycle': 272,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '273': {'cycle': 273,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '298': {'cycle': 298,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '299': {'cycle': 299,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '300': {'cycle': 300,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '325': {'cycle': 325,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '326': {'cycle': 326,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '327': {'cycle': 327,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '352': {'cycle': 352,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '353': {'cycle': 353,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '354': {'cycle': 354,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '379': {'cycle': 379,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '380': {'cycle': 380,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '381': {'cycle': 381,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '406': {'cycle': 406,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '407': {'cycle': 407,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '408': {'cycle': 408,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '433': {'cycle': 433,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '434': {'cycle': 434,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '435': {'cycle': 435,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '460': {'cycle': 460,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '461': {'cycle': 461,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '462': {'cycle': 462,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '487': {'cycle': 487,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '488': {'cycle': 488,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '489': {'cycle': 489,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    '514': {'cycle': 514,
#     'node_id': 'node_0',
#     'inventory': 0,
#     'last_production': 200},
#    
metadata
# Out:
#    node_id       node_class  max_inventory         cost_type edge_id  \
# 0   node_0   raw_material_1          200.0  negative_dynamic     NaN
# 1   node_1   raw_material_2          250.0  negative_dynamic     NaN
# 2   node_2   raw_material_3          220.0             fixed     NaN
# 3   node_3  intermediate_a1          300.0  negative_dynamic     NaN
# 4   node_4  intermediate_a2          280.0  negative_dynamic     NaN
# 5   node_5  intermediate_b1          300.0             fixed     NaN
# 6   node_6  intermediate_b2          280.0             fixed     NaN
# 7   node_7    final_product          350.0  negative_dynamic     NaN
# 8   node_8             sink            inf             fixed     NaN
# 9      NaN              NaN            NaN               NaN  edge_0
# 10     NaN              NaN            NaN               NaN  edge_1
# 11     NaN              NaN            NaN               NaN  edge_2
# 12     NaN              NaN            NaN               NaN  edge_3
# 13     NaN              NaN            NaN               NaN  edge_4
# 14     NaN              NaN            NaN               NaN  edge_5
# 15     NaN              NaN            NaN               NaN  edge_6
# 16     NaN              NaN            NaN               NaN  edge_7
# 17     NaN              NaN            NaN               NaN  edge_8
# 18     NaN              NaN            NaN               NaN  edge_9
#
#     source_node_id  target_node_id  unit_price  min_cost  max_cost
# 0              NaN             NaN         NaN       NaN       NaN
# 1              NaN             NaN         NaN       NaN       NaN
# 2              NaN             NaN         NaN       NaN       NaN
# 3              NaN             NaN         NaN       NaN       NaN
# 4              NaN             NaN         NaN       NaN       NaN
# 5              NaN             NaN         NaN       NaN       NaN
# 6              NaN             NaN         NaN       NaN       NaN
# 7              NaN             NaN         NaN       NaN       NaN
# 8              NaN             NaN         NaN       NaN       NaN
# 9              0.0             3.0        10.0       5.0      15.0
# 10             1.0             3.0        15.0       8.0      20.0
# 11             1.0             4.0        12.0       6.0      18.0
# 12             2.0             4.0        14.0       7.0      19.0
# 13             3.0             5.0        20.0      10.0      25.0
# 14             4.0             5.0        22.0      11.0      27.0
# 15             5.0             7.0        20.0      10.0      25.0
# 16             6.0             7.0        22.0      11.0      27.0
# 17             2.0             7.0        18.0       9.0      23.0
# 18             7.0             8.0        25.0      13.0      30.0

# %%
aggregated_nodes
# Out:
#       cycle node_id  inventory  last_production
# 0         1  node_0          0              200
# 1         2  node_0          0              200
# 2         3  node_0          0              200
# 3        28  node_0          0              200
# 4        29  node_0          0              200
# ...     ...     ...        ...              ...
# 5395   5372  node_8      19707              250
# 5396   5373  node_8      19707              250
# 5397   5398  node_8      19807              250
# 5398   5399  node_8      19807              250
# 5399   5400  node_8      19807              250
#
# [5400 rows x 4 columns]

# %%
aggregated_edges
# Out:
#       cycle edge_id  quantity  current_cost
# 0         1  edge_0        30          15.0
# 1         2  edge_0        30          15.0
# 2         3  edge_0        30          15.0
# 3        31  edge_0       200          15.0
# 4        32  edge_0       200          15.0
# ...     ...     ...       ...           ...
# 5995   5969  edge_9       350          30.0
# 5996   5970  edge_9       350          30.0
# 5997   5998  edge_9       350          30.0
# 5998   5999  edge_9       350          30.0
# 5999   6000  edge_9       350          30.0
#
# [6000 rows x 4 columns]
