# %% [markdown]
# # Generation of BoM Data for Supply Chain Simulation

# %%
SAVE_RECORDS=True

# %%
import sys
sys.path.append("..")

# %%
import random
import pandas as pd
import json
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import random
# ----> 2 import pandas as pd
#       3 import json
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
#      81     # missing
#      82     NA,
#      83     isna,
#      84     isnull,
#      85     notna,
#      86     notnull,
#      87     # indexes
#      88     Index,
#      89     CategoricalIndex,
#      90     RangeIndex,
#      91     MultiIndex,
#      92     IntervalIndex,
#      93     TimedeltaIndex,
#      94     DatetimeIndex,
#      95     PeriodIndex,
#      96     IndexSlice,
#      97     # tseries
#      98     NaT,
#      99     Period,
#     100     period_range,
#     101     Timedelta,
#     102     timedelta_range,
#     103     Timestamp,
#     104     date_range,
#     105     bdate_range,
#     106     Interval,
#     107     interval_range,
#     108     DateOffset,
#     109     # conversion
#     110     to_numeric,
#     111     to_datetime,
#     112     to_timedelta,
#     113     # misc
#     114     Flags,
#     115     Grouper,
#     116     factorize,
#     117     unique,
#     118     value_counts,
#     119     NamedAgg,
#     120     array,
#     121     Categorical,
#     122     set_eng_float_format,
#     123     Series,
#     124     DataFrame,
#     125 )
#     127 from pandas.core.dtypes.dtypes import SparseDtype
#     129 from pandas.tseries.api import infer_freq
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py:28
#      16 from pandas.core.dtypes.missing import (
#      17     isna,
#      18     isnull,
#      19     notna,
#      20     notnull,
#      21 )
#      23 from pandas.core.algorithms import (
#      24     factorize,
#      25     unique,
#      26     value_counts,
#      27 )
# ---> 28 from pandas.core.arrays import Categorical
#      29 from pandas.core.arrays.boolean import BooleanDtype
#      30 from pandas.core.arrays.floating import (
#      31     Float32Dtype,
#      32     Float64Dtype,
#      33 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\__init__.py:9
#       7 from pandas.core.arrays.boolean import BooleanArray
#       8 from pandas.core.arrays.categorical import Categorical
# ----> 9 from pandas.core.arrays.datetimes import DatetimeArray
#      10 from pandas.core.arrays.floating import FloatingArray
#      11 from pandas.core.arrays.integer import IntegerArray
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimes.py:62
#      55 from pandas.core.dtypes.dtypes import (
#      56     DatetimeTZDtype,
#      57     ExtensionDtype,
#      58     PeriodDtype,
#      59 )
#      60 from pandas.core.dtypes.missing import isna
# ---> 62 from pandas.core.arrays import datetimelike as dtl
#      63 from pandas.core.arrays._ranges import generate_regular_range
#      64 import pandas.core.common as com
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\datetimelike.py:121
#     110 from pandas.core import (
#     111     algorithms,
#     112     missing,
#     113     nanops,
#     114     ops,
#     115 )
#     116 from pandas.core.algorithms import (
#     117     isin,
#     118     map_array,
#     119     unique1d,
#     120 )
# --> 121 from pandas.core.array_algos import datetimelike_accumulations
#     122 from pandas.core.arraylike import OpsMixin
#     123 from pandas.core.arrays._mixins import (
#     124     NDArrayBackedExtensionArray,
#     125     ravel_compat,
#     126 )
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:990, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1086, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1186, in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Mock Supply Chain

# %%
from core.supply_chain import SupplyChain, LeafNode, CombinerNode, SinkNode

def create_supply_chain():
    supply_chain = SupplyChain()

    # Create leaf nodes with random cost types
    leaf1 = LeafNode(200, "raw_material_1", [(0, 10), (5, 15), (10, 20)], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    leaf2 = LeafNode(250, "raw_material_2", [(0, 15), (5, 20), (10, 25)], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    leaf3 = LeafNode(220, "raw_material_3", [(0, 12), (5, 18), (10, 22)], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(leaf1)
    supply_chain.add_node(leaf2)
    supply_chain.add_node(leaf3)

    # Create intermediate nodes with random cost types
    intermediate_a1 = CombinerNode(300, "intermediate_a1", [0.8, 1.0], [1, 1.2], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    intermediate_a2 = CombinerNode(280, "intermediate_a2", [0.9, 1.1], [1.1, 1.3], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(intermediate_a1)
    supply_chain.add_node(intermediate_a2)

    intermediate_b1 = CombinerNode(300, "intermediate_b1", [0.8, 1.0], [1, 1.2], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    intermediate_b2 = CombinerNode(280, "intermediate_b2", [0.9, 1.1], [1.1, 1.3], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(intermediate_b1)
    supply_chain.add_node(intermediate_b2)

    # Create final combiner node with random cost type
    final_combiner = CombinerNode(350, "final_product", [0.7, 0.8, 0.9], [1, 1.1, 1.2], random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(final_combiner)

    # Create sink node with random cost type
    sink = SinkNode(consumption_rate=250, cost_type=random.choice(["fixed", "positive_dynamic", "negative_dynamic"]))
    supply_chain.add_node(sink)

    # Add edges with cost ranges
    supply_chain.add_edge(leaf1, intermediate_a1, 10, 30, 5, 15)
    supply_chain.add_edge(leaf2, intermediate_a1, 15, 35, 8, 20)
    supply_chain.add_edge(leaf2, intermediate_a2, 12, 30, 6, 18)
    supply_chain.add_edge(leaf3, intermediate_a2, 14, 32, 7, 19)
    supply_chain.add_edge(intermediate_a1, intermediate_b1, 20, 40, 10, 25)
    supply_chain.add_edge(intermediate_a2, intermediate_b1, 22, 42, 11, 27)
    supply_chain.add_edge(intermediate_b1, final_combiner, 20, 40, 10, 25)
    supply_chain.add_edge(intermediate_b2, final_combiner, 22, 42, 11, 27)
    supply_chain.add_edge(leaf3, final_combiner, 18, 35, 9, 23)
    supply_chain.add_edge(final_combiner, sink, 25, 50, 13, 30)

    return supply_chain

# %%
# Simulation
time = 0
supply_chain = create_supply_chain()

for _ in range(200):  # Simulate for 200 time steps
    supply_chain.update()
    time += 1

    # Print current state
    print(f"Time: {time}")
    for node in supply_chain.nodes:
        print(f"Node ({node.node_class}): Inventory = {node.inventory}, Last Production = {node.last_production}, Cost Type = {node.cost_type}")
        for edge, target_node in node.outgoing_edges:
            print(f"  Edge to {target_node.node_class}: Quantity = {edge.quantity}, Cost = {edge.current_cost:.2f}")
    print("---")
# Out:
# Time: 1
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 30, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 35, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 30, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 32, Cost = 7.38
#   Edge to final_product: Quantity = 35, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 95, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 137, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 42, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 120, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 40, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 42, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 140, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 50, Cost = 30.00
# Node (sink): Inventory = 0, Last Production = 50, Cost Type = negative_dynamic
# ---
# Time: 2
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 160, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 199, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 0, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 202, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 141, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 257, Cost = 30.00
# Node (sink): Inventory = 7, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 3
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 80, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 300, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 43, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 350, Cost = 30.00
# Node (sink): Inventory = 107, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 4
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 144, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 110, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 350, Cost = 30.00
# Node (sink): Inventory = 207, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 5
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 262, Cost = 30.00
# Node (sink): Inventory = 219, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 6
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 258, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 7
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 275, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 8
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 314, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 9
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 331, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 10
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 370, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 11
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 387, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 12
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 426, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 13
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 443, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 14
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 482, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 15
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 499, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 16
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 538, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 17
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 555, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 18
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 594, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 19
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 611, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 20
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 650, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 21
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 667, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 22
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 706, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 23
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 723, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 24
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 762, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 25
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 779, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 26
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 818, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 27
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 835, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 28
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 874, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 29
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 891, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 30
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 930, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 31
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 947, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 32
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 986, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 33
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 1003, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 34
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 1042, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 35
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 1059, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 36
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 1098, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 37
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# ...
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 5354, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 189
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 5371, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 190
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 5410, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 191
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 5427, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 192
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 5466, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 193
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 5483, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 194
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 5522, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 195
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 5539, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 196
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 5578, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 197
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 5595, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 198
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 5634, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 199
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 8, Cost = 8.34
#   Edge to intermediate_a2: Quantity = 7, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 6, Cost = 7.44
#   Edge to final_product: Quantity = 6, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 20, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 40, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 18, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 26, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 81, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 161, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 121, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 267, Cost = 30.00
# Node (sink): Inventory = 5651, Last Production = 250, Cost Type = negative_dynamic
# ---
# Time: 200
# Node (raw_material_1): Inventory = 0, Last Production = 10, Cost Type = fixed
#   Edge to intermediate_a1: Quantity = 10, Cost = 10.00
# Node (raw_material_2): Inventory = 1, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_a1: Quantity = 9, Cost = 8.38
#   Edge to intermediate_a2: Quantity = 6, Cost = 6.05
# Node (raw_material_3): Inventory = 1, Last Production = 12, Cost Type = positive_dynamic
#   Edge to intermediate_a2: Quantity = 5, Cost = 7.38
#   Edge to final_product: Quantity = 7, Cost = 9.06
# Node (intermediate_a1): Inventory = 0, Last Production = 21, Cost Type = negative_dynamic
#   Edge to intermediate_b1: Quantity = 38, Cost = 25.00
# Node (intermediate_a2): Inventory = 0, Last Production = 15, Cost Type = positive_dynamic
#   Edge to intermediate_b1: Quantity = 31, Cost = 11.00
# Node (intermediate_b1): Inventory = 0, Last Production = 92, Cost Type = negative_dynamic
#   Edge to final_product: Quantity = 147, Cost = 25.00
# Node (intermediate_b2): Inventory = 0, Last Production = 1, Cost Type = fixed
#   Edge to final_product: Quantity = 1, Cost = 19.00
# Node (final_product): Inventory = 0, Last Production = 112, Cost Type = negative_dynamic
#   Edge to sink: Quantity = 289, Cost = 30.00
# Node (sink): Inventory = 5690, Last Production = 250, Cost Type = negative_dynamic
# ---

# %% [markdown]
# ## Recording of the simulation

# %%
from core.simulate import simulate_and_collect_data

# %%
supply_chain = create_supply_chain()
metadata_df, node_data_df, edge_data_df = simulate_and_collect_data(supply_chain, n_cycles=20)

# %%
metadata_df
# Out:
#    node_id       node_class  max_inventory         cost_type edge_id  \
# 0        0   raw_material_1          200.0  positive_dynamic     NaN
# 1        1   raw_material_2          250.0  negative_dynamic     NaN
# 2        2   raw_material_3          220.0  negative_dynamic     NaN
# 3        3  intermediate_a1          300.0  negative_dynamic     NaN
# 4        4  intermediate_a2          280.0  positive_dynamic     NaN
# 5        5  intermediate_b1          300.0  negative_dynamic     NaN
# 6        6  intermediate_b2          280.0  positive_dynamic     NaN
# 7        7    final_product          350.0             fixed     NaN
# 8        8             sink            inf             fixed     NaN
# 9      NaN              NaN            NaN               NaN       0
# 10     NaN              NaN            NaN               NaN       1
# 11     NaN              NaN            NaN               NaN       2
# 12     NaN              NaN            NaN               NaN       3
# 13     NaN              NaN            NaN               NaN       4
# 14     NaN              NaN            NaN               NaN       5
# 15     NaN              NaN            NaN               NaN       6
# 16     NaN              NaN            NaN               NaN       7
# 17     NaN              NaN            NaN               NaN       8
# 18     NaN              NaN            NaN               NaN       9
#
#    source_node_id target_node_id  unit_price  min_cost  max_cost
# 0             NaN            NaN         NaN       NaN       NaN
# 1             NaN            NaN         NaN       NaN       NaN
# 2             NaN            NaN         NaN       NaN       NaN
# 3             NaN            NaN         NaN       NaN       NaN
# 4             NaN            NaN         NaN       NaN       NaN
# 5             NaN            NaN         NaN       NaN       NaN
# 6             NaN            NaN         NaN       NaN       NaN
# 7             NaN            NaN         NaN       NaN       NaN
# 8             NaN            NaN         NaN       NaN       NaN
# 9               0              3        10.0       5.0      15.0
# 10              1              3        15.0       8.0      20.0
# 11              1              4        12.0       6.0      18.0
# 12              2              4        14.0       7.0      19.0
# 13              3              5        20.0      10.0      25.0
# 14              4              5        22.0      11.0      27.0
# 15              5              7        20.0      10.0      25.0
# 16              6              7        22.0      11.0      27.0
# 17              2              7        18.0       9.0      23.0
# 18              7              8        25.0      13.0      30.0

# %%
node_data_df
# Out:
#      cycle node_id  inventory  last_production
# 0        0       0          0               10
# 1        0       1          1               15
# 2        0       2          1               12
# 3        0       3          0               95
# 4        0       4          0              137
# ..     ...     ...        ...              ...
# 175     19       4          0               15
# 176     19       5          0               92
# 177     19       6          0                1
# 178     19       7          0              112
# 179     19       8        650              250
#
# [180 rows x 4 columns]

# %%
edge_data_df
# Out:
#      cycle edge_id  quantity  current_cost
# 0        0       0        30      5.000000
# 1        0       1        35     19.664000
# 2        0       2        30     17.952000
# 3        0       3        32     18.618182
# 4        0       4        40     25.000000
# ..     ...     ...       ...           ...
# 195     19       5        31     11.000000
# 196     19       6       147     25.000000
# 197     19       7         1     11.000000
# 198     19       8         7     22.936364
# 199     19       9       289     21.500000
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Conversion between JSON and DataFrames

# %%
from typing import Dict, List

def dataframes_to_json(metadata: pd.DataFrame, node: pd.DataFrame, edge: pd.DataFrame) -> str:
    bom = {
        "metadata": metadata.to_dict(orient='records'),
        "nodes": {},
        "edges": {}
    }

    # Process node data
    for _, row in node.iterrows():
        node_id = row['node_id']
        cycle = row['cycle']
        if node_id not in bom["nodes"]:
            bom["nodes"][node_id] = {}
        bom["nodes"][node_id][cycle] = row.to_dict()

    # Process edge data
    for _, row in edge.iterrows():
        edge_id = row['edge_id']
        cycle = row['cycle']
        if edge_id not in bom["edges"]:
            bom["edges"][edge_id] = {}
        bom["edges"][edge_id][cycle] = row.to_dict()

    return json.dumps(bom, indent=2)

def json_to_dataframes(json_data: str) -> Dict[str, pd.DataFrame]:
    bom = json.loads(json_data)

    # Create empty lists to store the data
    node_data = []
    edge_data = []

    # Process nodes
    for node_id, cycles in bom["nodes"].items():
        for cycle, node_info in cycles.items():
            node_data.append(node_info)

    # Process edges
    for edge_id, cycles in bom["edges"].items():
        for cycle, edge_info in cycles.items():
            edge_data.append(edge_info)

    # Create DataFrames
    metadata_df = pd.DataFrame(bom["metadata"])
    node_df = pd.DataFrame(node_data)
    edge_df = pd.DataFrame(edge_data)

    return {
        "metadata": metadata_df,
        "node": node_df,
        "edge": edge_df
    }

# %%
# Convert dataframes to JSON
json_string = dataframes_to_json(metadata_df, node_data_df, edge_data_df)

# %%
json_data = json.loads(json_string)
json_data
# Out:
# {'metadata': [{'node_id': '0',
#    'node_class': 'raw_material_1',
#    'max_inventory': 200.0,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '1',
#    'node_class': 'raw_material_2',
#    'max_inventory': 250.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '2',
#    'node_class': 'raw_material_3',
#    'max_inventory': 220.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '3',
#    'node_class': 'intermediate_a1',
#    'max_inventory': 300.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '4',
#    'node_class': 'intermediate_a2',
#    'max_inventory': 280.0,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '5',
#    'node_class': 'intermediate_b1',
#    'max_inventory': 300.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '6',
#    'node_class': 'intermediate_b2',
#    'max_inventory': 280.0,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '7',
#    'node_class': 'final_product',
#    'max_inventory': 350.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '8',
#    'node_class': 'sink',
#    'max_inventory': inf,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '0',
#    'source_node_id': '0',
#    'target_node_id': '3',
#    'unit_price': 10.0,
#    'min_cost': 5.0,
#    'max_cost': 15.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '1',
#    'source_node_id': '1',
#    'target_node_id': '3',
#    'unit_price': 15.0,
#    'min_cost': 8.0,
#    'max_cost': 20.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '2',
#    'source_node_id': '1',
#    'target_node_id': '4',
#    'unit_price': 12.0,
#    'min_cost': 6.0,
#    'max_cost': 18.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '3',
#    'source_node_id': '2',
#    'target_node_id': '4',
#    'unit_price': 14.0,
#    'min_cost': 7.0,
#    'max_cost': 19.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '4',
#    'source_node_id': '3',
#    'target_node_id': '5',
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '5',
#    'source_node_id': '4',
#    'target_node_id': '5',
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '6',
#    'source_node_id': '5',
#    'target_node_id': '7',
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '7',
#    'source_node_id': '6',
#    'target_node_id': '7',
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '8',
#    'source_node_id': '2',
#    'target_node_id': '7',
#    'unit_price': 18.0,
#    'min_cost': 9.0,
#    'max_cost': 23.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '9',
#    'source_node_id': '7',
#    'target_node_id': '8',
#    'unit_price': 25.0,
#    'min_cost': 13.0,
#    'max_cost': 30.0}],
#  'nodes': {'0': {'0': {'cycle': 0,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '1': {'cycle': 1, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '2': {'cycle': 2, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '3': {'cycle': 3, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '4': {'cycle': 4, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '5': {'cycle': 5, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '6': {'cycle': 6, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '7': {'cycle': 7, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '8': {'cycle': 8, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '9': {'cycle': 9, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '10': {'cycle': 10, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '11': {'cycle': 11, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '12': {'cycle': 12, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '13': {'cycle': 13, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '14': {'cycle': 14, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '15': {'cycle': 15, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '16': {'cycle': 16, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '17': {'cycle': 17, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '18': {'cycle': 18, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '19': {'cycle': 19, 'node_id': '0', 'inventory': 0, 'last_production': 10}},
#   '1': {'0': {'cycle': 0,
#     'node_id': '1',
#     'inventory': 1,
#     'last_production': 15},
#    '1': {'cycle': 1, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '2': {'cycle': 2, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '3': {'cycle': 3, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '4': {'cycle': 4, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '5': {'cycle': 5, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '6': {'cycle': 6, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '7': {'cycle': 7, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '8': {'cycle': 8, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '9': {'cycle': 9, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '10': {'cycle': 10, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '11': {'cycle': 11, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '12': {'cycle': 12, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '13': {'cycle': 13, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '14': {'cycle': 14, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '15': {'cycle': 15, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '16': {'cycle': 16, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '17': {'cycle': 17, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '18': {'cycle': 18, 'node_id': '1', 'inventory': 1, 'last_production': 15},
#    '19': {'cycle': 19, 'node_id': '1', 'inventory': 1, 'last_production': 15}},
#   '2': {'0': {'cycle': 0,
#     'node_id': '2',
#     'inventory': 1,
#     'last_production': 12},
#    '1': {'cycle': 1, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '2': {'cycle': 2, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '3': {'cycle': 3, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '4': {'cycle': 4, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '5': {'cycle': 5, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '6': {'cycle': 6, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '7': {'cycle': 7, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '8': {'cycle': 8, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '9': {'cycle': 9, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '10': {'cycle': 10, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '11': {'cycle': 11, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '12': {'cycle': 12, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '13': {'cycle': 13, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '14': {'cycle': 14, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '15': {'cycle': 15, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '16': {'cycle': 16, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '17': {'cycle': 17, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '18': {'cycle': 18, 'node_id': '2', 'inventory': 1, 'last_production': 12},
#    '19': {'cycle': 19, 'node_id': '2', 'inventory': 1, 'last_production': 12}},
#   '3': {'0': {'cycle': 0,
#     'node_id': '3',
#     'inventory': 0,
#     'last_production': 95},
#    '1': {'cycle': 1, 'node_id': '3', 'inventory': 0, 'last_production': 20},
#    '2': {'cycle': 2, 'node_id': '3', 'inventory': 0, 'last_production': 20},
#    '3': {'cycle': 3, 'node_id': '3', 'inventory': 0, 'last_production': 21},
#    '4': {'cycle': 4, 'node_id': '3', 'inventory': 0, 'last_production': 20},
#    '5': {'cycle': 5, 'node_id': '3', 'inventory': 0, 'last_production': 21},
#    '6': {'cycle': 6, 'node_id': '3', 'inventory': 0, 'last_production': 20},
#    '7': {'cycle': 7, 'node_id': '3', 'inventory': 0, 'last_production': 21},
#    '8': {'cycle': 8, 'node_id': '3', 'inventory': 0, 'last_production': 20},
#    
 'node_id': '8', 'inventory': 7, 'last_production': 250},
#    '2': {'cycle': 2, 'node_id': '8', 'inventory': 107, 'last_production': 250},
#    '3': {'cycle': 3, 'node_id': '8', 'inventory': 207, 'last_production': 250},
#    '4': {'cycle': 4, 'node_id': '8', 'inventory': 219, 'last_production': 250},
#    '5': {'cycle': 5, 'node_id': '8', 'inventory': 258, 'last_production': 250},
#    '6': {'cycle': 6, 'node_id': '8', 'inventory': 275, 'last_production': 250},
#    '7': {'cycle': 7, 'node_id': '8', 'inventory': 314, 'last_production': 250},
#    '8': {'cycle': 8, 'node_id': '8', 'inventory': 331, 'last_production': 250},
#    '9': {'cycle': 9, 'node_id': '8', 'inventory': 370, 'last_production': 250},
#    '10': {'cycle': 10,
#     'node_id': '8',
#     'inventory': 387,
#     'last_production': 250},
#    '11': {'cycle': 11,
#     'node_id': '8',
#     'inventory': 426,
#     'last_production': 250},
#    '12': {'cycle': 12,
#     'node_id': '8',
#     'inventory': 443,
#     'last_production': 250},
#    '13': {'cycle': 13,
#     'node_id': '8',
#     'inventory': 482,
#     'last_production': 250},
#    '14': {'cycle': 14,
#     'node_id': '8',
#     'inventory': 499,
#     'last_production': 250},
#    '15': {'cycle': 15,
#     'node_id': '8',
#     'inventory': 538,
#     'last_production': 250},
#    '16': {'cycle': 16,
#     'node_id': '8',
#     'inventory': 555,
#     'last_production': 250},
#    '17': {'cycle': 17,
#     'node_id': '8',
#     'inventory': 594,
#     'last_production': 250},
#    '18': {'cycle': 18,
#     'node_id': '8',
#     'inventory': 611,
#     'last_production': 250},
#    '19': {'cycle': 19,
#     'node_id': '8',
#     'inventory': 650,
#     'last_production': 250}}},
#  'edges': {'0': {'0': {'cycle': 0,
#     'edge_id': '0',
#     'quantity': 30,
#     'current_cost': 5.0},
#    '1': {'cycle': 1, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '2': {'cycle': 2, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '3': {'cycle': 3, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '4': {'cycle': 4, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '5': {'cycle': 5, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '6': {'cycle': 6, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '7': {'cycle': 7, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '8': {'cycle': 8, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '9': {'cycle': 9, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '10': {'cycle': 10, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '11': {'cycle': 11, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '12': {'cycle': 12, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '13': {'cycle': 13, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '14': {'cycle': 14, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '15': {'cycle': 15, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '16': {'cycle': 16, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '17': {'cycle': 17, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '18': {'cycle': 18, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '19': {'cycle': 19, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0}},
#   '1': {'0': {'cycle': 0,
#     'edge_id': '1',
#     'quantity': 35,
#     'current_cost': 19.664},
#    '1': {'cycle': 1, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.616},
#    '2': {'cycle': 2, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.664},
#    '3': {'cycle': 3, 'edge_id': '1', 'quantity': 9, 'current_cost': 19.616},
#    '4': {'cycle': 4, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.664},
#    '5': {'cycle': 5, 'edge_id': '1', 'quantity': 9, 'current_cost': 19.616},
#    '6': {'cycle': 6, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.664},
#    '7': {'cycle': 7, 'edge_id': '1', 'quantity': 9, 'current_cost': 19.616},
#    '8': {'cycle': 8, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.664},
#    '9': {'cycle': 9, 'edge_id': '1', 'quantity': 9, 'current_cost': 19.616},
#    '10': {'cycle': 10, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.664},
#    '11': {'cycle': 11, 'edge_id': '1', 'quantity': 9, 'current_cost': 19.616},
#    '12': {'cycle': 12, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.664},
#    '13': {'cycle': 13, 'edge_id': '1', 'quantity': 9, 'current_cost': 19.616},
#    '14': {'cycle': 14, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.664},
#    '15': {'cycle': 15, 'edge_id': '1', 'quantity': 9, 'current_cost': 19.616},
#    '16': {'cycle': 16, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.664},
#    '17': {'cycle': 17, 'edge_id': '1', 'quantity': 9, 'current_cost': 19.616},
#    '18': {'cycle': 18, 'edge_id': '1', 'quantity': 8, 'current_cost': 19.664},
#    '19': {'cycle': 19, 'edge_id': '1', 'quantity': 9, 'current_cost': 19.616}},
#   '2': {'0': {'cycle': 0,
#     'edge_id': '2',
#     'quantity': 30,
#     'current_cost': 17.951999999999998},
#    '1': {'cycle': 1,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '2': {'cycle': 2,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '3': {'cycle': 3,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '4': {'cycle': 4,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '5': {'cycle': 5,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '6': {'cycle': 6,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '7': {'cycle': 7,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '8': {'cycle': 8,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '9': {'cycle': 9,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '10': {'cycle': 10,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '11': {'cycle': 11,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '12': {'cycle': 12,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '13': {'cycle': 13,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '14': {'cycle': 14,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '15': {'cycle': 15,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '16': {'cycle': 16,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '17': {'cycle': 17,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '18': {'cycle': 18,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '19': {'cycle': 19,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998}},
#   '3': {'0': {'cycle': 0,
#     'edge_id': '3',
#     'quantity': 32,
#     'current_cost': 18.618181818181817},
#    '1': {'cycle': 1,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '2': {'cycle': 2,
#     'edge_id': '3',
#     'quantity': 6,
#     'current_cost': 18.563636363636363},
#    '3': {'cycle': 3,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '4': {'cycle': 4,
#     'edge_id': '3',
#     'quantity': 6,
#     'current_cost': 18.563636363636363},
#    '5': {'cycle': 5,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '6': {'cycle': 6,
#     'edge_id': '3',
#     'quantity': 6,
#     'current_cost': 18.563636363636363},
#    '7': {'cycle': 7,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '8': {'cycle': 8,
#     'edge_id': '3',
#     'quantity': 6,
#     'current_cost': 18.563636363636363},
#    '9': {'cycle': 9,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '10': {'cycle': 10,
#     'edge_id': '3',
#     'quantity': 6,
#     'current_cost': 18.563636363636363},
#    '11': {'cycle': 11,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '12': {'cycle': 12,
#     'edge_id': '3',
#     'quantity': 6,
#     'current_cost': 18.563636363636363},
#    '13': {'cycle': 13,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '14': {'cycle': 14,
#     'edge_id': '3',
#     'quantity': 6,
#     'current_cost': 18.563636363636363},
#    '15': {'cycle': 15,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '16': {'cycle': 16,
#     'edge_id': '3',
#     'quantity': 6,
#     'current_cost': 18.563636363636363},
#    '17': {'cycle': 17,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '18': {'cycle': 18,
#     'edge_id': '3',
#     'quantity': 6,
#     'current_cost': 18.563636363636363},
#    '19': {'cycle': 19,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817}},
#   '4': {'0': {'cycle': 0,
#     'edge_id': '4',
#     'quantity': 40,
#     'current_cost': 25.0},
#    '1': {'cycle': 1, 'edge_id': '4', 'quantity': 160, 'current_cost': 25.0},
#    '2': {'cycle': 2, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0},
#    '3': {'cycle': 3, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0},
#    '4': {'cycle': 4, 'edge_id': '4', 'quantity': 40, 'current_cost': 25.0},
#    '5': {'cycle': 5, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0},
#    '6': {'cycle': 6, 'edge_id': '4', 'quantity': 40, 'current_cost': 25.0},
#    '7': {'cycle': 7, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0},
#    '8': {'cycle': 8, 'edge_id': '4', 'quantity': 40, 'current_cost': 25.0},
#    '9': {'cycle': 9, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0},
#    '10': {'cycle': 10, 'edge_id': '4', 'quantity': 40, 'current_cost': 25.0},
#    '11': {'cycle': 11, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0},
#    '12': {'cycle': 12, 'edge_id': '4', 'quantity': 40, 'current_cost': 25.0},
#    '13': {'cycle': 13, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0},
#    '14': {'cycle': 14, 'edge_id': '4', 'quantity': 40, 'current_cost': 25.0},
#    '15': {'cycle': 15, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0},
#    '16': {'cycle': 16, 'edge_id': '4', 'quantity': 40, 'current_cost': 25.0},
#    '17': {'cycle': 17, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0},
#    '18': {'cycle': 18, 'edge_id': '4', 'quantity': 40, 'current_cost': 25.0},
#    '19': {'cycle': 19, 'edge_id': '4', 'quantity': 38, 'current_cost': 25.0}},
#   '5': {'0': {'cycle': 0,
#     'edge_id': '5',
#     'quantity': 42,
#     'current_cost': 11.0},
#    '1': {'cycle': 1, 'edge_id': '5', 'quantity': 199, 'current_cost': 11.0},
#    '2': {'cycle': 2, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '3': {'cycle': 3, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '4': {'cycle': 4, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '5': {'cycle': 5, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '6': {'cycle': 6, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '7': {'cycle': 7, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '8': {'cycle': 8, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '9': {'cycle': 9, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '10': {'cycle': 10, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '11': {'cycle': 11, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '12': {'cycle': 12, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '13': {'cycle': 13, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '14': {'cycle': 14, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '15': {'cycle': 15, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '16': {'cycle': 16, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '17': {'cycle': 17, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '18': {'cycle': 18, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '19': {'cycle': 19, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0}},
#   '6': {'0': {'cycle': 0,
#     'edge_id': '6',
#     'quantity': 40,
#     'current_cost': 25.0},
#    '1': {'cycle': 1, 'edge_id': '6', 'quantity': 202, 'current_cost': 25.0},
#    '2': {'cycle': 2, 'edge_id': '6', 'quantity': 300, 'current_cost': 25.0},
#    '3': {'cycle': 3, 'edge_id': '6', 'quantity': 144, 'current_cost': 25.0},
#    '4': {'cycle': 4, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '5': {'cycle': 5, 'edge_id': '6', 'quantity': 147, 'current_cost': 25.0},
#    '6': {'cycle': 6, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '7': {'cycle': 7, 'edge_id': '6', 'quantity': 147, 'current_cost': 25.0},
#    '8': {'cycle': 8, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '9': {'cycle': 9, 'edge_id': '6', 'quantity': 147, 'current_cost': 25.0},
#    '10': {'cycle': 10, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '11': {'cycle': 11, 'edge_id': '6', 'quantity': 147, 'current_cost': 25.0},
#    '12': {'cycle': 12, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '13': {'cycle': 13, 'edge_id': '6', 'quantity': 147, 'current_cost': 25.0},
#    '14': {'cycle': 14, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '15': {'cycle': 15, 'edge_id': '6', 'quantity': 147, 'current_cost': 25.0},
#    '16': {'cycle': 16, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '17': {'cycle': 17, 'edge_id': '6', 'quantity': 147, 'current_cost': 25.0},
#    '18': {'cycle': 18, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '19': {'cycle': 19, 'edge_id': '6', 'quantity': 147, 'current_cost': 25.0}},
#   '7': {'0': {'cycle': 0,
#     'edge_id': '7',
#     'quantity': 42,
#     'current_cost': 11.0},
#    '1': {'cycle': 1, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '2': {'cycle': 2, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '3': {'cycle': 3, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '4': {'cycle': 4, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '5': {'cycle': 5, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '6': {'cycle': 6, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '7': {'cycle': 7, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '8': {'cycle': 8, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '9': {'cycle': 9, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '10': {'cycle': 10, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '11': {'cycle': 11, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '12': {'cycle': 12, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '13': {'cycle': 13, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '14': {'cycle': 14, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '15': {'cycle': 15, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '16': {'cycle': 16, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '17': {'cycle': 17, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '18': {'cycle': 18, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0},
#    '19': {'cycle': 19, 'edge_id': '7', 'quantity': 1, 'current_cost': 11.0}},
#   '8': {'0': {'cycle': 0,
#     'edge_id': '8',
#     'quantity': 35,
#     'current_cost': 22.936363636363637},
#    '1': {'cycle': 1,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '2': {'cycle': 2,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '3': {'cycle': 3,
#     'edge_id': '8',
#     'quantity': 7,
#     'current_cost': 22.936363636363637},
#    '4': {'cycle': 4,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '5': {'cycle': 5,
#     'edge_id': '8',
#     'quantity': 7,
#     'current_cost': 22.936363636363637},
#    '6': {'cycle': 6,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '7': {'cycle': 7,
#     'edge_id': '8',
#     'quantity': 7,
#     'current_cost': 22.936363636363637},
#    '8': {'cycle': 8,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '9': {'cycle': 9,
#     'edge_id': '8',
#     'quantity': 7,
#     'current_cost': 22.936363636363637},
#    '10': {'cycle': 10,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '11': {'cycle': 11,
#     'edge_id': '8',
#     'quantity': 7,
#     'current_cost': 22.936363636363637},
#    '12': {'cycle': 12,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '13': {'cycle': 13,
#     'edge_id': '8',
#     'quantity': 7,
#     'current_cost': 22.936363636363637},
#    '14': {'cycle': 14,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '15': {'cycle': 15,
#     'edge_id': '8',
#     'quantity': 7,
#     'current_cost': 22.936363636363637},
#    '16': {'cycle': 16,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '17': {'cycle': 17,
#     'edge_id': '8',
#     'quantity': 7,
#     'current_cost': 22.936363636363637},
#    '18': {'cycle': 18,
#     'edge_id': '8',
#     'quantity': 6,
#     'current_cost': 22.936363636363637},
#    '19': {'cycle': 19,
#     'edge_id': '8',
#     'quantity': 7,
#     'current_cost': 22.936363636363637}},
#   '9': {'0': {'cycle': 0,
#     'edge_id': '9',
#     'quantity': 50,
#     'current_cost': 21.5},
#    '1': {'cycle': 1, 'edge_id': '9', 'quantity': 257, 'current_cost': 21.5},
#    '2': {'cycle': 2, 'edge_id': '9', 'quantity': 350, 'current_cost': 21.5},
#    '3': {'cycle': 3, 'edge_id': '9', 'quantity': 350, 'current_cost': 21.5},
#    '4': {'cycle': 4, 'edge_id': '9', 'quantity': 262, 'current_cost': 21.5},
#    '5': {'cycle': 5, 'edge_id': '9', 'quantity': 289, 'current_cost': 21.5},
#    '6': {'cycle': 6, 'edge_id': '9', 'quantity': 267, 'current_cost': 21.5},
#    '7': {'cycle': 7, 'edge_id': '9', 'quantity': 289, 'current_cost': 21.5},
#    '8': {'cycle': 8, 'edge_id': '9', 'quantity': 267, 'current_cost': 21.5},
#    '9': {'cycle': 9, 'edge_id': '9', 'quantity': 289, 'current_cost': 21.5},
#    '10': {'cycle': 10, 'edge_id': '9', 'quantity': 267, 'current_cost': 21.5},
#    '11': {'cycle': 11, 'edge_id': '9', 'quantity': 289, 'current_cost': 21.5},
#    '12': {'cycle': 12, 'edge_id': '9', 'quantity': 267, 'current_cost': 21.5},
#    '13': {'cycle': 13, 'edge_id': '9', 'quantity': 289, 'current_cost': 21.5},
#    '14': {'cycle': 14, 'edge_id': '9', 'quantity': 267, 'current_cost': 21.5},
#    '15': {'cycle': 15, 'edge_id': '9', 'quantity': 289, 'current_cost': 21.5},
#    '16': {'cycle': 16, 'edge_id': '9', 'quantity': 267, 'current_cost': 21.5},
#    '17': {'cycle': 17, 'edge_id': '9', 'quantity': 289, 'current_cost': 21.5},
#    '18': {'cycle': 18, 'edge_id': '9', 'quantity': 267, 'current_cost': 21.5},
#    '19': {'cycle': 19,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5}}}}

# %%
if SAVE_RECORDS:
    with open('../data/json/true.json', 'w') as f:
        json.dump(json_data, f, ensure_ascii=False)

# %%
# Convert JSON back to dataframes
reconstructed_dfs = json_to_dataframes(json_string)

# Access the reconstructed dataframes
reconstructed_metadata = reconstructed_dfs['metadata']
reconstructed_node = reconstructed_dfs['node']
reconstructed_edge = reconstructed_dfs['edge']

# %%
if SAVE_RECORDS:
    reconstructed_metadata.to_csv('../data/csv/metadata.csv', index=False)
    reconstructed_node.to_csv('../data/csv/node.csv', index=False)
    reconstructed_edge.to_csv('../data/csv/edge.csv', index=False)

# %%
reconstructed_metadata
# Out:
#    node_id       node_class  max_inventory         cost_type edge_id  \
# 0        0   raw_material_1          200.0  positive_dynamic     NaN
# 1        1   raw_material_2          250.0  negative_dynamic     NaN
# 2        2   raw_material_3          220.0  negative_dynamic     NaN
# 3        3  intermediate_a1          300.0  negative_dynamic     NaN
# 4        4  intermediate_a2          280.0  positive_dynamic     NaN
# 5        5  intermediate_b1          300.0  negative_dynamic     NaN
# 6        6  intermediate_b2          280.0  positive_dynamic     NaN
# 7        7    final_product          350.0             fixed     NaN
# 8        8             sink            inf             fixed     NaN
# 9      NaN              NaN            NaN               NaN       0
# 10     NaN              NaN            NaN               NaN       1
# 11     NaN              NaN            NaN               NaN       2
# 12     NaN              NaN            NaN               NaN       3
# 13     NaN              NaN            NaN               NaN       4
# 14     NaN              NaN            NaN               NaN       5
# 15     NaN              NaN            NaN               NaN       6
# 16     NaN              NaN            NaN               NaN       7
# 17     NaN              NaN            NaN               NaN       8
# 18     NaN              NaN            NaN               NaN       9
#
#    source_node_id target_node_id  unit_price  min_cost  max_cost
# 0             NaN            NaN         NaN       NaN       NaN
# 1             NaN            NaN         NaN       NaN       NaN
# 2             NaN            NaN         NaN       NaN       NaN
# 3             NaN            NaN         NaN       NaN       NaN
# 4             NaN            NaN         NaN       NaN       NaN
# 5             NaN            NaN         NaN       NaN       NaN
# 6             NaN            NaN         NaN       NaN       NaN
# 7             NaN            NaN         NaN       NaN       NaN
# 8             NaN            NaN         NaN       NaN       NaN
# 9               0              3        10.0       5.0      15.0
# 10              1              3        15.0       8.0      20.0
# 11              1              4        12.0       6.0      18.0
# 12              2              4        14.0       7.0      19.0
# 13              3              5        20.0      10.0      25.0
# 14              4              5        22.0      11.0      27.0
# 15              5              7        20.0      10.0      25.0
# 16              6              7        22.0      11.0      27.0
# 17              2              7        18.0       9.0      23.0
# 18              7              8        25.0      13.0      30.0

# %%
reconstructed_node
# Out:
#      cycle node_id  inventory  last_production
# 0        0       0          0               10
# 1        1       0          0               10
# 2        2       0          0               10
# 3        3       0          0               10
# 4        4       0          0               10
# ..     ...     ...        ...              ...
# 175     15       8        538              250
# 176     16       8        555              250
# 177     17       8        594              250
# 178     18       8        611              250
# 179     19       8        650              250
#
# [180 rows x 4 columns]

# %%
reconstructed_edge
# Out:
#      cycle edge_id  quantity  current_cost
# 0        0       0        30           5.0
# 1        1       0        10           5.0
# 2        2       0        10           5.0
# 3        3       0        10           5.0
# 4        4       0        10           5.0
# ..     ...     ...       ...           ...
# 195     15       9       289          21.5
# 196     16       9       267          21.5
# 197     17       9       289          21.5
# 198     18       9       267          21.5
# 199     19       9       289          21.5
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Aggredation of Cycles and Conversion between JSON and Dataframes

# %%
from typing import Dict

def aggregated_dataframes_to_json(metadata: pd.DataFrame, node: pd.DataFrame, edge: pd.DataFrame, max_aggregation_cycles: int = 3) -> str:
    bom = {
        "metadata": metadata.to_dict(orient='records'),
        "nodes": {},
        "edges": {}
    }

    # Initialize variables to track the last cycle
    last_node_cycle = 0
    last_edge_cycle = 0
    
    num_cycles_to_aggregate = random.randint(1, max_aggregation_cycles)

    # Process node data with aggregation
    for _, row in node.iterrows():
        node_id = row['node_id']
        cycle = row['cycle']
        # Check if we can aggregate
        if node_id not in bom["nodes"]:
            bom["nodes"][node_id] = {}
        
        # Aggregate nodes
        for _ in range(num_cycles_to_aggregate):
            last_node_cycle += 1
            # Create a new entry for the aggregated node
            aggregated_node = row.copy()
            aggregated_node['cycle'] = last_node_cycle
            bom["nodes"][node_id][last_node_cycle] = aggregated_node.to_dict()

    # Process edge data with aggregation
    for _, row in edge.iterrows():
        edge_id = row['edge_id']
        cycle = row['cycle']
        # Check if we can aggregate
        if edge_id not in bom["edges"]:
            bom["edges"][edge_id] = {}
        
        # Aggregate edges
        for _ in range(num_cycles_to_aggregate):
            last_edge_cycle += 1
            # Create a new entry for the aggregated edge
            aggregated_edge = row.copy()
            aggregated_edge['cycle'] = last_edge_cycle
            bom["edges"][edge_id][last_edge_cycle] = aggregated_edge.to_dict()

    return json.dumps(bom, indent=2)

# %%
aggregated_json = aggregated_dataframes_to_json(metadata_df, node_data_df, edge_data_df)
aggregated_json_dict = json.loads(aggregated_json)

aggregated_json_dict
# Out:
# {'metadata': [{'node_id': '0',
#    'node_class': 'raw_material_1',
#    'max_inventory': 200.0,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '1',
#    'node_class': 'raw_material_2',
#    'max_inventory': 250.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '2',
#    'node_class': 'raw_material_3',
#    'max_inventory': 220.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '3',
#    'node_class': 'intermediate_a1',
#    'max_inventory': 300.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '4',
#    'node_class': 'intermediate_a2',
#    'max_inventory': 280.0,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '5',
#    'node_class': 'intermediate_b1',
#    'max_inventory': 300.0,
#    'cost_type': 'negative_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '6',
#    'node_class': 'intermediate_b2',
#    'max_inventory': 280.0,
#    'cost_type': 'positive_dynamic',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '7',
#    'node_class': 'final_product',
#    'max_inventory': 350.0,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': '8',
#    'node_class': 'sink',
#    'max_inventory': inf,
#    'cost_type': 'fixed',
#    'edge_id': nan,
#    'source_node_id': nan,
#    'target_node_id': nan,
#    'unit_price': nan,
#    'min_cost': nan,
#    'max_cost': nan},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '0',
#    'source_node_id': '0',
#    'target_node_id': '3',
#    'unit_price': 10.0,
#    'min_cost': 5.0,
#    'max_cost': 15.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '1',
#    'source_node_id': '1',
#    'target_node_id': '3',
#    'unit_price': 15.0,
#    'min_cost': 8.0,
#    'max_cost': 20.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '2',
#    'source_node_id': '1',
#    'target_node_id': '4',
#    'unit_price': 12.0,
#    'min_cost': 6.0,
#    'max_cost': 18.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '3',
#    'source_node_id': '2',
#    'target_node_id': '4',
#    'unit_price': 14.0,
#    'min_cost': 7.0,
#    'max_cost': 19.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '4',
#    'source_node_id': '3',
#    'target_node_id': '5',
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '5',
#    'source_node_id': '4',
#    'target_node_id': '5',
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '6',
#    'source_node_id': '5',
#    'target_node_id': '7',
#    'unit_price': 20.0,
#    'min_cost': 10.0,
#    'max_cost': 25.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '7',
#    'source_node_id': '6',
#    'target_node_id': '7',
#    'unit_price': 22.0,
#    'min_cost': 11.0,
#    'max_cost': 27.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '8',
#    'source_node_id': '2',
#    'target_node_id': '7',
#    'unit_price': 18.0,
#    'min_cost': 9.0,
#    'max_cost': 23.0},
#   {'node_id': nan,
#    'node_class': nan,
#    'max_inventory': nan,
#    'cost_type': nan,
#    'edge_id': '9',
#    'source_node_id': '7',
#    'target_node_id': '8',
#    'unit_price': 25.0,
#    'min_cost': 13.0,
#    'max_cost': 30.0}],
#  'nodes': {'0': {'1': {'cycle': 1,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '2': {'cycle': 2, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '19': {'cycle': 19, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '20': {'cycle': 20, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '37': {'cycle': 37, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '38': {'cycle': 38, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '55': {'cycle': 55, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '56': {'cycle': 56, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '73': {'cycle': 73, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '74': {'cycle': 74, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '91': {'cycle': 91, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '92': {'cycle': 92, 'node_id': '0', 'inventory': 0, 'last_production': 10},
#    '109': {'cycle': 109,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '110': {'cycle': 110,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '127': {'cycle': 127,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '128': {'cycle': 128,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '145': {'cycle': 145,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '146': {'cycle': 146,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '163': {'cycle': 163,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '164': {'cycle': 164,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '181': {'cycle': 181,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    '182': {'cycle': 182,
#     'node_id': '0',
#     'inventory': 0,
#     'last_production': 10},
#    
#     'node_id': '8',
#     'inventory': 275,
#     'last_production': 250},
#    '143': {'cycle': 143,
#     'node_id': '8',
#     'inventory': 314,
#     'last_production': 250},
#    '144': {'cycle': 144,
#     'node_id': '8',
#     'inventory': 314,
#     'last_production': 250},
#    '161': {'cycle': 161,
#     'node_id': '8',
#     'inventory': 331,
#     'last_production': 250},
#    '162': {'cycle': 162,
#     'node_id': '8',
#     'inventory': 331,
#     'last_production': 250},
#    '179': {'cycle': 179,
#     'node_id': '8',
#     'inventory': 370,
#     'last_production': 250},
#    '180': {'cycle': 180,
#     'node_id': '8',
#     'inventory': 370,
#     'last_production': 250},
#    '197': {'cycle': 197,
#     'node_id': '8',
#     'inventory': 387,
#     'last_production': 250},
#    '198': {'cycle': 198,
#     'node_id': '8',
#     'inventory': 387,
#     'last_production': 250},
#    '215': {'cycle': 215,
#     'node_id': '8',
#     'inventory': 426,
#     'last_production': 250},
#    '216': {'cycle': 216,
#     'node_id': '8',
#     'inventory': 426,
#     'last_production': 250},
#    '233': {'cycle': 233,
#     'node_id': '8',
#     'inventory': 443,
#     'last_production': 250},
#    '234': {'cycle': 234,
#     'node_id': '8',
#     'inventory': 443,
#     'last_production': 250},
#    '251': {'cycle': 251,
#     'node_id': '8',
#     'inventory': 482,
#     'last_production': 250},
#    '252': {'cycle': 252,
#     'node_id': '8',
#     'inventory': 482,
#     'last_production': 250},
#    '269': {'cycle': 269,
#     'node_id': '8',
#     'inventory': 499,
#     'last_production': 250},
#    '270': {'cycle': 270,
#     'node_id': '8',
#     'inventory': 499,
#     'last_production': 250},
#    '287': {'cycle': 287,
#     'node_id': '8',
#     'inventory': 538,
#     'last_production': 250},
#    '288': {'cycle': 288,
#     'node_id': '8',
#     'inventory': 538,
#     'last_production': 250},
#    '305': {'cycle': 305,
#     'node_id': '8',
#     'inventory': 555,
#     'last_production': 250},
#    '306': {'cycle': 306,
#     'node_id': '8',
#     'inventory': 555,
#     'last_production': 250},
#    '323': {'cycle': 323,
#     'node_id': '8',
#     'inventory': 594,
#     'last_production': 250},
#    '324': {'cycle': 324,
#     'node_id': '8',
#     'inventory': 594,
#     'last_production': 250},
#    '341': {'cycle': 341,
#     'node_id': '8',
#     'inventory': 611,
#     'last_production': 250},
#    '342': {'cycle': 342,
#     'node_id': '8',
#     'inventory': 611,
#     'last_production': 250},
#    '359': {'cycle': 359,
#     'node_id': '8',
#     'inventory': 650,
#     'last_production': 250},
#    '360': {'cycle': 360,
#     'node_id': '8',
#     'inventory': 650,
#     'last_production': 250}}},
#  'edges': {'0': {'1': {'cycle': 1,
#     'edge_id': '0',
#     'quantity': 30,
#     'current_cost': 5.0},
#    '2': {'cycle': 2, 'edge_id': '0', 'quantity': 30, 'current_cost': 5.0},
#    '21': {'cycle': 21, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '22': {'cycle': 22, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '41': {'cycle': 41, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '42': {'cycle': 42, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '61': {'cycle': 61, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '62': {'cycle': 62, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '81': {'cycle': 81, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '82': {'cycle': 82, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '101': {'cycle': 101, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '102': {'cycle': 102, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '121': {'cycle': 121, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '122': {'cycle': 122, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    '141': {'cycle': 141, 'edge_id': '0', 'quantity': 10, 'current_cost': 5.0},
#    

#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '285': {'cycle': 285,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '286': {'cycle': 286,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '305': {'cycle': 305,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '306': {'cycle': 306,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '325': {'cycle': 325,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '326': {'cycle': 326,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '345': {'cycle': 345,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '346': {'cycle': 346,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '365': {'cycle': 365,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '366': {'cycle': 366,
#     'edge_id': '2',
#     'quantity': 7,
#     'current_cost': 17.951999999999998},
#    '385': {'cycle': 385,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998},
#    '386': {'cycle': 386,
#     'edge_id': '2',
#     'quantity': 6,
#     'current_cost': 17.951999999999998}},
#   '3': {'7': {'cycle': 7,
#     'edge_id': '3',
#     'quantity': 32,
#     'current_cost': 18.618181818181817},
#    '8': {'cycle': 8,
#     'edge_id': '3',
#     'quantity': 32,
#     'current_cost': 18.618181818181817},
#    '27': {'cycle': 27,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '28': {'cycle': 28,
#     'edge_id': '3',
#     'quantity': 5,
#     'current_cost': 18.618181818181817},
#    '47': {'cycle': 47,
#     'edge_id': '3',
#     'quantity': 6,
# ...
#    '232': {'cycle': 232, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '251': {'cycle': 251, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '252': {'cycle': 252, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '271': {'cycle': 271, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '272': {'cycle': 272, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '291': {'cycle': 291, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '292': {'cycle': 292, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '311': {'cycle': 311, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '312': {'cycle': 312, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '331': {'cycle': 331, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '332': {'cycle': 332, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '351': {'cycle': 351, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '352': {'cycle': 352, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '371': {'cycle': 371, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '372': {'cycle': 372, 'edge_id': '5', 'quantity': 26, 'current_cost': 11.0},
#    '391': {'cycle': 391, 'edge_id': '5', 'quantity': 31, 'current_cost': 11.0},
#    '392': {'cycle': 392,
#     'edge_id': '5',
#     'quantity': 31,
#     'current_cost': 11.0}},
#   '6': {'13': {'cycle': 13,
#     'edge_id': '6',
#     'quantity': 40,
#     'current_cost': 25.0},
#    '14': {'cycle': 14, 'edge_id': '6', 'quantity': 40, 'current_cost': 25.0},
#    '33': {'cycle': 33, 'edge_id': '6', 'quantity': 202, 'current_cost': 25.0},
#    '34': {'cycle': 34, 'edge_id': '6', 'quantity': 202, 'current_cost': 25.0},
#    '53': {'cycle': 53, 'edge_id': '6', 'quantity': 300, 'current_cost': 25.0},
#    '54': {'cycle': 54, 'edge_id': '6', 'quantity': 300, 'current_cost': 25.0},
#    '73': {'cycle': 73, 'edge_id': '6', 'quantity': 144, 'current_cost': 25.0},
#    '74': {'cycle': 74, 'edge_id': '6', 'quantity': 144, 'current_cost': 25.0},
#    '93': {'cycle': 93, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '94': {'cycle': 94, 'edge_id': '6', 'quantity': 161, 'current_cost': 25.0},
#    '113': {'cycle': 113,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '114': {'cycle': 114,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '133': {'cycle': 133,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '134': {'cycle': 134,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '153': {'cycle': 153,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '154': {'cycle': 154,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '173': {'cycle': 173,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '174': {'cycle': 174,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '193': {'cycle': 193,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '194': {'cycle': 194,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '213': {'cycle': 213,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '214': {'cycle': 214,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '233': {'cycle': 233,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '234': {'cycle': 234,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '253': {'cycle': 253,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '254': {'cycle': 254,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '273': {'cycle': 273,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '274': {'cycle': 274,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '293': {'cycle': 293,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '294': {'cycle': 294,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '313': {'cycle': 313,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '314': {'cycle': 314,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '333': {'cycle': 333,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '334': {'cycle': 334,
#     'edge_id': '6',
#     'quantity': 161,
#     'current_cost': 25.0},
#    '353': {'cycle': 353,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    '354': {'cycle': 354,
#     'edge_id': '6',
#     'quantity': 147,
#     'current_cost': 25.0},
#    
 'edge_id': '9', 'quantity': 350, 'current_cost': 21.5},
#    '60': {'cycle': 60, 'edge_id': '9', 'quantity': 350, 'current_cost': 21.5},
#    '79': {'cycle': 79, 'edge_id': '9', 'quantity': 350, 'current_cost': 21.5},
#    '80': {'cycle': 80, 'edge_id': '9', 'quantity': 350, 'current_cost': 21.5},
#    '99': {'cycle': 99, 'edge_id': '9', 'quantity': 262, 'current_cost': 21.5},
#    '100': {'cycle': 100,
#     'edge_id': '9',
#     'quantity': 262,
#     'current_cost': 21.5},
#    '119': {'cycle': 119,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '120': {'cycle': 120,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '139': {'cycle': 139,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '140': {'cycle': 140,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '159': {'cycle': 159,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '160': {'cycle': 160,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '179': {'cycle': 179,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '180': {'cycle': 180,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '199': {'cycle': 199,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '200': {'cycle': 200,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '219': {'cycle': 219,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '220': {'cycle': 220,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '239': {'cycle': 239,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '240': {'cycle': 240,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '259': {'cycle': 259,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '260': {'cycle': 260,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '279': {'cycle': 279,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '280': {'cycle': 280,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '299': {'cycle': 299,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '300': {'cycle': 300,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '319': {'cycle': 319,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '320': {'cycle': 320,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '339': {'cycle': 339,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '340': {'cycle': 340,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '359': {'cycle': 359,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '360': {'cycle': 360,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '379': {'cycle': 379,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '380': {'cycle': 380,
#     'edge_id': '9',
#     'quantity': 267,
#     'current_cost': 21.5},
#    '399': {'cycle': 399,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5},
#    '400': {'cycle': 400,
#     'edge_id': '9',
#     'quantity': 289,
#     'current_cost': 21.5}}}}

# %%
if SAVE_RECORDS:
    import json
    with open('../data/json/aggregated.json', 'w') as f:
        json.dump(aggregated_json_dict, f, ensure_ascii=False)

# %%
aggregated_dataframe = json_to_dataframes(aggregated_json)

aggregated_metadata = aggregated_dataframe["metadata"]
aggregated_nodes = aggregated_dataframe["node"]
aggregated_edges = aggregated_dataframe["edge"]

# %%
if SAVE_RECORDS:
    aggregated_metadata.to_csv("../data/csv/aggregated_metadata.csv", index=False)
    aggregated_nodes.to_csv("../data/csv/aggregated_node_data.csv", index=False)
    aggregated_edges.to_csv("../data/csv/aggregated_edge_data.csv", index=False)

# %%
aggregated_metadata
# Out:
#    node_id       node_class  max_inventory         cost_type edge_id  \
# 0        0   raw_material_1          200.0  positive_dynamic     NaN
# 1        1   raw_material_2          250.0  negative_dynamic     NaN
# 2        2   raw_material_3          220.0  negative_dynamic     NaN
# 3        3  intermediate_a1          300.0  negative_dynamic     NaN
# 4        4  intermediate_a2          280.0  positive_dynamic     NaN
# 5        5  intermediate_b1          300.0  negative_dynamic     NaN
# 6        6  intermediate_b2          280.0  positive_dynamic     NaN
# 7        7    final_product          350.0             fixed     NaN
# 8        8             sink            inf             fixed     NaN
# 9      NaN              NaN            NaN               NaN       0
# 10     NaN              NaN            NaN               NaN       1
# 11     NaN              NaN            NaN               NaN       2
# 12     NaN              NaN            NaN               NaN       3
# 13     NaN              NaN            NaN               NaN       4
# 14     NaN              NaN            NaN               NaN       5
# 15     NaN              NaN            NaN               NaN       6
# 16     NaN              NaN            NaN               NaN       7
# 17     NaN              NaN            NaN               NaN       8
# 18     NaN              NaN            NaN               NaN       9
#
#    source_node_id target_node_id  unit_price  min_cost  max_cost
# 0             NaN            NaN         NaN       NaN       NaN
# 1             NaN            NaN         NaN       NaN       NaN
# 2             NaN            NaN         NaN       NaN       NaN
# 3             NaN            NaN         NaN       NaN       NaN
# 4             NaN            NaN         NaN       NaN       NaN
# 5             NaN            NaN         NaN       NaN       NaN
# 6             NaN            NaN         NaN       NaN       NaN
# 7             NaN            NaN         NaN       NaN       NaN
# 8             NaN            NaN         NaN       NaN       NaN
# 9               0              3        10.0       5.0      15.0
# 10              1              3        15.0       8.0      20.0
# 11              1              4        12.0       6.0      18.0
# 12              2              4        14.0       7.0      19.0
# 13              3              5        20.0      10.0      25.0
# 14              4              5        22.0      11.0      27.0
# 15              5              7        20.0      10.0      25.0
# 16              6              7        22.0      11.0      27.0
# 17              2              7        18.0       9.0      23.0
# 18              7              8        25.0      13.0      30.0

# %%
aggregated_nodes
# Out:
#      cycle node_id  inventory  last_production
# 0        1       0          0               10
# 1        2       0          0               10
# 2       19       0          0               10
# 3       20       0          0               10
# 4       37       0          0               10
# ..     ...     ...        ...              ...
# 355    324       8        594              250
# 356    341       8        611              250
# 357    342       8        611              250
# 358    359       8        650              250
# 359    360       8        650              250
#
# [360 rows x 4 columns]

# %%
aggregated_edges
# Out:
#      cycle edge_id  quantity  current_cost
# 0        1       0        30           5.0
# 1        2       0        30           5.0
# 2       21       0        10           5.0
# 3       22       0        10           5.0
# 4       41       0        10           5.0
# ..     ...     ...       ...           ...
# 395    360       9       289          21.5
# 396    379       9       267          21.5
# 397    380       9       267          21.5
# 398    399       9       289          21.5
# 399    400       9       289          21.5
#
# [400 rows x 4 columns]
